# %% [markdown]
# # Курсовая работа № 2
# ## Аналитика. Начальный уровень
#
# Курсовая работа состоит из двух частей – обязательной и дополнительной. **Для зачета необходимо выполнение только первой части.** Выполнение второй части может потребовать дополнительные знания Python.
#
# - [Часть первая](#Часть-первая)
# - [Часть вторая](#Часть-вторая)

# %% [markdown]
# ## Часть первая
#
#
# Перед вами стоит задача – подготовить аналитический отчет для HR-отдела. На основании проведенной аналитики предполагается составить рекомендации для отдела кадров по стратегии набора персонала, а также по взаимодействию с уже имеющимися сотрудниками.
# <br><br> В базе данных лежит набор таблиц, которые содержат данные о сотрудниках вымышленной компании.
# Сделайте обзор штата сотрудников компании. Составьте набор предметов исследования, а затем проверьте их на данных. Вся аналитика должна быть выполена с помощью SQL. Впоследствии данные можно визуализировать, однако финальные датафреймы для графиков также должны быть подготовлены с помощью SQL. <br><br>
#
# Примеры гипотез:
# 1. Есть зависимость между `perfomance score` и тем, под чьим руководством работает сотрудник.
# 2. Есть зависимость между продолжительностью работы в компании и семейным положением сотрудника.
# 2. Есть зависимость между продолжительностью работы в компании и возрастом сотрудника.
#
# <br><br>
# Параметры для подключения следующие: хост – `dsstudents.skillbox.ru`, порт – `5432`, имя базы данных – `human_resources`, пользователь – `readonly`, пароль – `6hajV34RTQfmxhS`. Таблицы, доступные для анализа, – `hr_dataset`, `production_staff`, `recruting_costs`, `salary_grid`.

# %% [markdown]
# ## Гипотеза №1

# %%
# Импортируем нужные библиотеки
import psycopg2
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import numpy as np

# Создаем подключение к базе данных
pg_connection = {
    "host": "dsstudents.skillbox.ru",
    "port": 5432,
    "dbname": "human_resources",
    "user": "readonly",
    "password": "6hajV34RTQfmxhS"
}

conn = psycopg2.connect(**pg_connection)
cursor = conn.cursor()
# посмотрим, какие таблицы есть в бд
sql_str = "SELECT table_name FROM information_schema.tables WHERE table_schema='public';"
cursor.execute(sql_str)
tables_data = [a for a in cursor.fetchall()]
conn.commit()

print("какие таблицы есть в бд: %s" % tables_data)
# Out:
# какие таблицы есть в бд: [('hr_dataset',), ('production_staff',), ('male',), ('female',), ('recruiting_costs',), ('hr_dataset_view',), ('numb_of_hire',), ('numb_of_terms',), ('salary_grid',), ('days_work',), ('show_functions',), ('abu_pay',), ('abupay1',), ('share_employee_source',), ('tmpDB',), ('abupay',), ('contacts',)]

# %%
# Создал датафрейм, для просмотра названий колонок.
df_hr = pd.read_sql_query("SELECT * FROM public.hr_dataset LIMIT 5;", conn)
df_hr
# Out:
#    id         Employee Name  Employee Number  marriedid  maritalstatusid  \
# 0   1            Brown, Mia       1103024456          1                1
# 1   2  LaRotonda, William         1106026572          0                2
# 2   3      Steans, Tyrone         1302053333          0                0
# 3   4       Howard, Estelle       1211050782          1                1
# 4   5           Singh, Nan        1307059817          0                0
#
#    genderid  empstatus_id  deptid  perf_scoreid  age  ...  Date of Hire  \
# 0         0             1       1             3   30  ...    2008-10-27
# 1         1             1       1             3   34  ...    2014-01-06
# 2         1             1       1             3   31  ...    2014-09-29
# 3         0             1       1             9   32  ...    2015-02-16
# 4         0             1       1             9   30  ...    2015-05-01
#
#   Days Employed  Date of Termination       Reason For Term Employment Status  \
# 0          3317                 None  N/A - still employed            Active
# 1          1420                 None  N/A - still employed            Active
# 2          1154                 None  N/A - still employed            Active
# 3            58           2015-04-15  N/A - still employed            Active
# 4           940                 None  N/A - still employed            Active
#
#       department                  position        Manager Name  \
# 0  Admin Offices              Accountant I  Brandon R. LeBlanc
# 1  Admin Offices              Accountant I  Brandon R. LeBlanc
# 2  Admin Offices              Accountant I  Brandon R. LeBlanc
# 3  Admin Offices  Administrative Assistant  Brandon R. LeBlanc
# 4  Admin Offices  Administrative Assistant  Brandon R. LeBlanc
#
#           Employee Source         Performance Score
# 0      Diversity Job Fair               Fully Meets
# 1      Website Banner Ads               Fully Meets
# 2         Internet Search               Fully Meets
# 3  Pay Per Click - Google  N/A- too early to review
# 4      Website Banner Ads  N/A- too early to review
#
# [5 rows x 29 columns]

# %%
# Проверяем, есть зависимость между perfomance score и тем, под чьим руководством работает сотрудник.

# Создаю подключение к базе
conn = psycopg2.connect(**pg_connection)
# Создаю объект курсора
cursor = conn.cursor()

# Создаю запрос к базе данных, в которых выбираю имена менеджеров, оценку производительности и их кол-во из таблицы hr_dataset
sql_str = 'SELECT "Manager Name", "Performance Score", COUNT(*) FROM public.hr_dataset GROUP BY "Manager Name", "Performance Score";'
# извлекаю запрос
cursor.execute(sql_str)
# Все данные полученные из запроса присваиваю переменной
newlist = cursor.fetchall()
# Сохранил изменения
conn.commit()
# Закрываем подключение к бд
conn.close()

# %%
# Создаю пустой словарь
perf_dict= {}
# Наполняем пустой словарь ключами из имен менеджеров
[perf_dict.update({x[0]:{}}) for x in newlist]
perf_dict
# Out:
# {'Amy Dunn': {},
#  'Lynn Daneault': {},
#  'Webster Butler': {},
#  'David Stanley': {},
#  'Simon Roup': {},
#  'Brannon Miller': {},
#  'Brandon R. LeBlanc': {},
#  'Kissy Sullivan': {},
#  'Ketsia Liebig': {},
#  'Eric Dougall': {},
#  'Elijiah Gray': {},
#  'Kelley Spirea': {},
#  'Janet King': {},
#  'Michael Albert': {},
#  'Peter Monroe': {},
#  'Alex Sweetwater': {},
#  'Jennifer Zamora': {},
#  'John Smith': {},
#  'Board of Directors': {},
#  'Debra Houlihan': {},
#  'Brian Champaigne': {}}

# %%
# Запускаем цикл по данным  полученным из базы данных
for row in newlist:
    name = row[0]
    perf_score = row[1]
    count = row[2]
    perf_dict[name].update({perf_score:count})

# %%
# Преобразую словарь в датафрейм
df_perf_score = pd.DataFrame(perf_dict).T

# Из полученных данных, создаю график
ax = df_perf_score.plot.barh(fontsize=12, figsize=(15,15), width=1, title='Зависимость между perfomance score и тем, под чьим руководством работает сотрудник')
ax.set_xlabel("Performance Score")
ax.set_ylabel("Manager Name")
# Out:
# Text(0, 0.5, 'Manager Name')

# %% [markdown]
# ## Вывод:
# Исходя из графика, мы видем следующее:
#
# 1. Практически у всех менеджеров большинство сотрудников полностью соответствуют требованиям
#
# 2. У Michael Albert показатели сторудников не соответсвует текущим требованиям
#
# 3. Косаемо гипотезы, можно сделать следующий вывод, как видно на графике у Brian Champaigne сотрудники полностью соответсвовали всем требованиям, и на основании его показателей можно утерждать, что есть зависимость между perfomance score и тем, под чьим руководством работает сотрудник.

# %% [markdown]
# ## Гипотеза №2

# %%
# Создаю подключение к базе
conn = psycopg2.connect(**pg_connection)
# Создаю объект курсора
cursor = conn.cursor()

# Создаю запрос к базе данных
sql_str = 'SELECT "maritalstatusid", percentile_disc(0.5) within group (order by public.hr_dataset."Days Employed") from public.hr_dataset GROUP BY "maritalstatusid"'
# извлекаю запрос
cursor.execute(sql_str)
# Все данные полученные из запроса присваиваю переменной
newlist = cursor.fetchall()
# Сохранил изменения
conn.commit()
# Закрываем подключение к бд
conn.close()

# %%
# Создаю датафрейм из полученных в запросе данных
df = pd.DataFrame(newlist, columns=['maritalstatusid', 'Days']).set_index('maritalstatusid')

ax = df.plot.barh(figsize=(13, 8), title='Зависимость между продолжительностью работы в компании и семейным положением сотрудника.')

ax.set_xlabel("Days")
ax.set_ylabel("maritalstatusid")
# Out:
# Text(0, 0.5, 'maritalstatusid')

# %% [markdown]
# ## Вывод по графику №1:
# Как видно из графика, в большинстве случаев дольше всех работает категория людей, котрые были трижды в браке.

# %%
# Создаю подключение к базе
conn = psycopg2.connect(**pg_connection)
# Создаю объект курсора
cursor = conn.cursor()

# Создаю запрос к базе данных
sql_str = 'SELECT "marriedid", percentile_disc(0.5) within group (order by public.hr_dataset."Days Employed") from public.hr_dataset GROUP BY "marriedid"'
# извлекаю запрос
cursor.execute(sql_str)
# Все данные полученные из запроса присваиваю переменной
newlist = cursor.fetchall()
# Сохранил изменения
conn.commit()
# Закрываем подключение к бд
conn.close()

# %%
# Создаю датафрейм из полученных в запросе данных
df = pd.DataFrame(newlist, columns=['marriedid', 'Days']).set_index('marriedid')

ax = df.plot.barh(figsize=(10, 8), title='Зависимость между продолжительностью работы в компании и семейным положением сотрудника.')
ax.set_xlabel("Days")
ax.set_ylabel("marriedid")
# Out:
# Text(0, 0.5, 'marriedid')

# %% [markdown]
# ## Вывод по графику №2:
# Как видно из графика №2, при детальном анализе, на  150 дней проработали больше сотрудники, которые не были в браке.
# Из 2 показателей графиков, можно сделать вывод, что гипотеза полностью подтвердилась, что есть зависимость между продолжительностью работы в компании и семейным положением сотрудника.

# %% [markdown]
# ## Гипотеза №3

# %%
# Создаю подключение к базе
conn = psycopg2.connect(**pg_connection)
# Создаю объект курсора
cursor = conn.cursor()

# Создаю запрос к базе данных
sql_str = 'select "age", percentile_disc(0.5) within group (order by public.hr_dataset."Days Employed") as days from public.hr_dataset GROUP BY "age" ORDER BY days'
# извлекаю запрос
cursor.execute(sql_str)
# Все данные полученные из запроса присваиваю переменной
newlist = cursor.fetchall()
# Сохранил изменения
conn.commit()
# Закрываем подключение к бд
conn.close()

# %%
df = pd.DataFrame(newlist, columns=['Age', 'Days']).set_index('Age').sort_index()

ax = df.plot(kind='barh', figsize=(15,15), title='Зависимость между продолжительностью работы в компании и возрастом сотрудника.')

ax.set_xlabel("Days")
ax.set_ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %% [markdown]
# ## Вывод по графику:
# Исходя из графика, дольше всех проработала категория возраста, кому за 49 лет. На мой взгляд, есть зависимость между продолжительностью работы в компании и возрастом сотрудника.
# Соответсвенно, данная гипотеза так же подтвердилась.

# %% [markdown]
# ## Часть вторая

# %% [markdown]
# Перед вами стоит задача – подготовить аналитический ответ для SMM-отдела компании Skillbox. <br> Объектом анализа является  [паблик Skillbox Вконтакте](https://vk.com/skillbox_education). <br> <br>
# Подключитесь к  API VK и выгрузите посты со стены паблика Skillbox за интересующий период (определите самостоятельно и обоснуйте). Проанализируйте влияние различных факторов (например, времени публикации) на вовлеченность пользователей (количество лайков, комментариев, голосов в опросах). Сделайте аналитику по рубрикам (примеры рубрик: дизайн-битва, игра по управлению), которые есть в паблике. Выбрать нужные посты можно с помощью регулярных выражений. Составьте перечень рекомандаций для SMM-отдела по итогам анализа. <br> <br>
#
# Дополнительные инструкции по работе с API VK расположены [здесь](https://nbviewer.jupyter.org/github/vikaborel/dstutorials/blob/master/Дополнительные%20инструкции.ipynb).

# %%
import requests

# Создал функцию которая извлекает json из спарсенных данных.
def getjson(url):
    response = requests.get(url)
    response = response.json()
    return response

# в данную переменную необходимо передать свой 'Сервисный ключ доступа', иначе скрип не сработает.
vk_token = #Token vk

# %%
# Получаю последние 100 записей из паблика Skillbox Вконтакте
# Данную выборку взял 100 последних постов, для анализа более свежой информации.
dict = {}

for i in range(100):
    dict[i] = {}
    url = 'https://api.vk.com/method/wall.get?access_token=' + str(vk_token) + f'&owner_id=-66669811&offset={i}&count=100&v=5.52'
    response = getjson(url)
    
    text = response['response']['items'][0]['text']
    likes = response['response']['items'][0]['likes']['count']
    reposts = response['response']['items'][0]['reposts']['count']
    
    date = response['response']['items'][0]['date']
    dt = (datetime.fromtimestamp(date) - timedelta(hours=0)).strftime('%Y-%m-%d %H:%M:%S')
    
    dict[i].update({'text':text,
                        'likes':likes,
                        'reposts':reposts,
                        'time':dt
                       
                       
                       
                       })

    print()
    print('Текст: ', text)
    print()
    print('Лайков: ', likes)
    print('Репостов: ', reposts)
    print('Время публикации: ', dt)
    print('*' * 40)
# Out:
# Текст:  Этими инструментами можно создать сайт своими руками, без дизайна и программирования.
#
# #Статья_Skillbox
#
# Лайков:  20
# Репостов:  0
# Время публикации:  2020-07-21 19:50:14
# ****************************************
#
# Текст:  Ждете новую лекцию цикла «Дизайн, философия и киборги»?
#
# Спешим обрадовать: она пройдет уже 22 июля в 19:00!
# Серж Степанищев расскажет о творчестве американского скульптора, арт-критика, основателя образовательного ресурса UbuWeb и поэта Кеннета Голдсмита.
#
# Подписывайтесь на бесплатный мини-курс и смотрите лекцию в прямом эфире. Начало — по московскому времени: https://vk.cc/axexhj
#
# #Skillbox_Дизайн
#
# Лайков:  6
# Репостов:  1
# Время публикации:  2020-07-21 17:06:25
# ****************************************
#
# Текст:  Тренировка для дизайнеров!
#
# Мы подготовили плакат, в котором намеренной допустили много ошибок в дизайне. Ваша задача — найти их и объяснить в комментариях, что не так. Вечером опубликуем список допущенных промахов и покажем, как надо было сверстать плакат правильно.
#
# Погнали!
#
# #Тренировка_Skillbox #Skillbox_дизайн
#
# Лайков:  27
# Репостов:  2
# Время публикации:  2020-07-21 13:13:17
# ****************************************
#
# Текст:  Полагаете, что “свободные” программы - это всегда бесплатно, с открытым кодом, и, в основном, для начинающих? Ничего подобного.
#
# #Статья_Skillbox
#
# Лайков:  15
# Репостов:  1
# Время публикации:  2020-07-20 20:28:34
# ****************************************
#
# Текст:  Готовы к новым знаниям? Неделя будет очень интенсивной! Мы расскажем о креативе в SMM, сделаем анимированный ролик, разработаем чат-бота с искусственным интеллектом, научимся поднимать конверсию лендинга на 30 % и еще многое-многое другое!
#
# Присоединяйтесь!
#
# Чтобы не пропустить интересующие вас вебинары, подпишитесь на рассылку. Раз в день или раз в неделю мы рассказываем о предстоящих вебинарах, а за 20 минут до начала присылаем ссылку на участие.
# 👉 https://vk.com/app6051158_-66669811
#
# Если не сможете принять участие в прямом эфире, смотрите в записи в любое удобное время здесь:
# 👉 https://vk.cc/9B4uhq
#
# #Расписание_Skillbox
#
# Лайков:  29
# Репостов:  1
# Время публикации:  2020-07-20 17:12:16
# ****************************************
#
# Текст:  У шахмат много плюсов: они прокачивают логику и стратегическое мышление, учат нестандартно мыслить, побеждать и принимать поражение с достоинством.
#
# Словом, игра полезна для студентов всех направлений Skillbox. Но с чего начать? Конечно, с первого хода! О самых сильных дебютных комбинациях, которые сможете повторить и вы, рассказываем в карточках 😎
#
# #В_закладки_Skillbox #Skillbox_программирование
#
# Лайков:  103
# Репостов:  16
# Время публикации:  2020-07-20 13:24:25
# ****************************************
#
# Текст:  В программировании самое главное — практика. Но и качественная теория точно не помешает.
# Автор курса Skillbox «Профессия Java-разработчик» Даниил Пилипенко и тимлид продюсеров курсов по программированию Игорь Музыкин опубликовали на VC.ru свою подборку книг для начинающих разработчиков. Делимся ею в наших карточках!
# Ознакомиться с полной версией статьи можно на сайте vc.ru
#
# #Советпрепода_Skillbox #Skillboxпрограммирование
#
# Лайков:  177
# Репостов:  31
# Время публикации:  2020-07-19 13:09:10
# ****************************************
#
# Текст:  Ностальгии пост.
#
# Помните, кто тоже любит «Мамбу»? А куда надо просто добавить воды? И что нужно выбирать — Tide или кипячение?
# Супер, вы настроились на нужную волну. Давайте вспомним рекламные ролики из 90-х, которые в свое время разобрали на цитаты. В комментариях присылайте ссылки на ту рекламу, которая особенно запомнилась вам.
#
# P.S. Если вы не застали эпоху 90-х, все равно посмотрите ролики — у маркетологов тех лет есть, чему поучиться. А если хотите сами показать класс — ждем вас на нашем курсе «Профессия Интернет-маркетолог»: https://vk.cc/ax4vHT
#
# ★ Mamba. Рекламная кампания «Все любят "Мамбу", и Сережа тоже» стала одним из ярчайших символов телевидения 90-х. В ролике щедрый мальчик в свой день рождения раздает друзьям сладкие подарки — жевательную конфету Mamba. Он перечисляет всех, кого угощает, и напоследок оставляет одну конфету себе — его зовут Сережа, и он тоже любит Mamba: https://vk.cc/ax4vKa
#
# ★ Invite. В 90-е у сока и лимонада была альтернатива — растворимые напитки, такие как Yupi, Zuko и Invite. Последний запомнился слоганом «Просто добавь воды» и рекламным роликом с актером Михаилом Багдасаровым: https://vk.cc/ax4vN5
#
# ★ ТВ-Парк. В маркетинговой кампании журнала было несколько роликов, пародирующих рекламные клише того времени. Например, в одном из них очевидная отсылка на ролик Blend-a-med с куриными яйцами. «Исследователь» опускает газету в кислоту, а журнал «ТВ-Парк» — в дистиллированную воду. Как итог — газета растворилась, а журнал остался невредим. Читайте «ТВ-парк», и ваш кислотно-щелочной баланс будет в порядке: https://vk.cc/5DUC5z
#
# #Skillbox_маркетинг #Кейс_Skillbox
#
# Лайков:  33
# Репостов:  1
# Время публикации:  2020-07-18 14:00:31
# ****************************************
#
# Текст:  Мы сделали гид по профессии копирайтера: рассказываем, что нужно уметь и как этому научиться, чтобы зарабатывать от 50 до 90 тыс. руб. в месяц.
#
# #Статья_Skillbox
#
# Лайков:  69
# Репостов:  4
# Время публикации:  2020-07-17 20:00:11
# ****************************************
#
# Текст:  С Днем эмоджи!
#
# Без них непросто выразить в тексте нужные эмоции, передать настроение или описать ситуацию. Когда не хватает слов, на помощь приходят они — эмоджи на все случаи жизни.
#
# Сейчас в любом мессенджере их так много, что вы вряд ли применяли хотя бы половину. А ведь еще несколько лет назад пользователям так не хватало стандартных наборов, что они скачивали новые версии ICQ и других приложений, надеясь увидеть дополненный комплект смайликов.
#
# А с чего все началось? Рассказываем в карточках!
#
# #Skillbox_маркетинг #В_закладки_Skillbox
#
# Лайков:  135
# Репостов:  16
# Время публикации:  2020-07-17 14:56:09
# ****************************************
#
# Текст:  Две трети стартапов умирают через год, грустная статистика. О том, как пройти “долину смерти”, рассказывает Дмитрий Панненков.
#
# #Статья_Skillbox
#
# Лайков:  27
# Репостов:  4
# Время публикации:  2020-07-16 19:50:49
# ****************************************
#
# Текст:  Хорошо разбираетесь в шрифтах? Давайте узнаем!
# Запустите наш тест и попробуйте определить, какой шрифт мы использовали в панграммах (это фразы, в которых есть почти все буквы алфавита).
#
# Предупреждаем: будет нелегко 😁
#
# #Игра_Skillbox #Skillbox_дизайн
#
# Лайков:  31
# Репостов:  0
# Время публикации:  2020-07-16 15:31:39
# ****************************************
#
# Текст:  Рассказываем о разных способах сделать хороший скриншот - на компьютере и телефоне.
#
# #Статья_Skillbox
#
# Лайков:  69
# Репостов:  11
# Время публикации:  2020-07-15 21:11:14
# ****************************************
#
# Текст:  Сколько лет нужно для создания игры? Нам хватило 5 минут! И у вас получится — в сервисе GIPHY можно делать собственные мини-аркады. Все очень просто: вы выбираете одну из 10 механик, затем — стикеры (можно взять готовые или подгрузить свои), определяетесь с фоном и музыкой, придумываете название — и вуаля!
#
# У нас получилась вот такая аркада. Го играть: https://vk.cc/awZh4y
# А в комментариях делитесь ссылками на свои игры!
#
# Кстати, чтобы собрать игру с нашими стикерами, просто введите «Skillbox» в поле поиска стикеров.
#
# #Skillbox_программирование #В_закладки_Skillbox
#
# Лайков:  47
# Репостов:  8
# Время публикации:  2020-07-15 17:01:12
# ****************************************
#
# Текст:  Капитал, суперскорость, избыточность высказывания, взлом виртуального – как все это связано с философией дизайна?
# Продолжаем наш цикл «Дизайн, философия и киборги». И на очереди лекция «Манифест хакера».
# В этот раз кандидат философских наук Серж Степанищев поговорит о философии неомарксистского писателя и теоретика медиа Маккензи Уорка.
# Начало 15 июля в 19:00 по Москве. Подписывайтесь на бесплатный мини-курс и смотрите лекцию в прямом эфире: https://vk.cc/awYX5Q
#
# #Skillbox_Дизайн
#
# Лайков:  21
# Репостов:  2
# Время публикации:  2020-07-15 15:01:15
# ****************************************
#
# Текст:  Знаний много не бывает! Даже если впереди сразу шесть лекций в онлайн-лектории Skillbox! Выбирайте, какие занятия хотели бы посетить, проходите по ссылкам и регистрируйтесь, чтобы посмотреть прямые трансляции.
# Начало эфира — по московскому времени.
#
# ★ 16 июля, 19:00. Как составить эффективное резюме. Руководитель группы анализа резюме Superjob Наталья Сергеева и ведущий IT-рекрутер, эксперт по карьерному консультированию Superjob Ольга Синельникова расскажут, как составить резюме, на которое точно обратят внимание рекрутеры и руководители, а также разберут резюме участников лекции, отметят сильные стороны и укажут на ошибки: https://vk.cc/awWqTT
#
# ★ 17 июля, 19:00. Name IT: креативные технологии нейминга. Президент ADCR, руководитель направления «Дизайн и реклама» Школы Дизайна НИУ ВШЭ Александр Алексеев познакомит с теорией и методиками нейминга, научит работать с брифом, предложит самостоятельно придумать название и даст профессиональный фидбэк: https://vk.cc/awWrnC
#
# ★ 18 июля, 13:00. Создаем свой фреймворк для разработки приложений. Ведущий разработчик IT-компании MediaSoft Андрей Черабаев разберет подходы в построении фреймворков, познакомит со структурой стандартного современного PHP-приложения, покажет, как написать свой микрофреймворк на PHP с нуля, и научит обходить неудобства стандартной библиотеки: https://vk.cc/awWrBa
#
# ★ 18 июля, 19:00. Дизайнер в США: переезд, поиск работы, новая жизнь. Ведущий дизайнер продукта MasterClass Михаил Белстар поделится своим опытом переезда в США, расскажет, как правильно искать работу, какую визу лучше получать дизайнерам и с чего начать новую жизнь в другой стране: https://vk.cc/awWrNi
#
# ★ 23 июля, 19:00. Митап по Vue.js: v-skillbox. Разработчик фреймворка Cube.js Леонид Яковлев расскажет, как делать конструктор отчетов при помощи cube.js на бэкленде; руководитель AFFINAGE Игорь Яковлев научит разрабатывать по-настоящему быстрые vue-приложения; разработчик «Московской биржи» Юлия Кузнецова объяснит, как GraphQL помогает решать проблемы REST API архитектуры: https://vk.cc/awWs2g
#
# ★ 28 июля, 19:00. Реактивные и нативные приложения на Java Spring и Quarkus. Разработчики в «МегаФоне» Сергей Кошкинов и Андрей Смирнов покажут процесс создания приложения на Java-фреймворке Quarkus с деплоем в MicroK8s и сравнят производительность и потребление памяти приложений Spring WebFlux, Spring Boot, Quarkus, Quarkus+Vert.x и скомпилированных в native code с помощью GraalVM: https://vk.cc/awWs9d
#
# #Лекторий_Skillbox
#
# Лайков:  42
# Репостов:  4
# Время публикации:  2020-07-14 15:45:19
# ****************************************
#
# Текст:  Отличить классика от нейросети? Звучит просто. Но так ли это на самом деле?
#
# Давайте проверим! Запустите наш тест и попробуйте определить, какое продолжение текста принадлежит перу известного писателя, а какое — всего лишь творчество нейросети.
#
# #Игра_Skillbox #Skillbox_программирование
#
# Лайков:  40
# Репостов:  3
# Время публикации:  2020-07-14 13:38:22
# ****************************************
#
# Текст:  “SMM-щик - это тот, кто пишет посты за деньги”. Так думают многие, но нет. Рассказываем, за что платят SMM-специалисту.
#
# #Статья_Skillbox
#
# Лайков:  62
# Репостов:  7
# Время публикации:  2020-07-13 22:02:47
# ****************************************
#
# Текст:  Новая неделя будет продуктивной 💪 В этот раз мы погрузимся в профессии Go-разработчика, проведем интенсив по геймдизайну и разберёмся в том, что такое креативная стратегия. И это еще далеко не все 😉
#
# Ждем вас!
#
# Чтобы не пропустить интересующие вас вебинары, подпишитесь на рассылку. Раз в день или раз в неделю мы рассказываем о предстоящих вебинарах, а за 20 минут до начала присылаем ссылку на участие.
# 👉 https://vk.com/app6051158_-66669811
#
# Если не сможете принять участие в прямом эфире, смотрите в записи в любое удобное время здесь:
# 👉 https://vk.cc/9B4uhq
#
# #Расписание_Skillbox
#
# Лайков:  34
# Репостов:  3
# Время публикации:  2020-07-13 15:21:33
# ****************************************
#
# Текст:  В дизайне помогает не только насмотренность, но и «наслушанность». Расширяйте свой профессиональный кругозор, не отрываясь от повседневных дел, — включайте дизайнерские подкасты и погружайтесь в творческую атмосферу.
# Смотрите подборку подкастов в наших карточках👆🏻
#
# #Skillbox_Дизайн #В_Закладки_Skillbox
#
# Лайков:  129
# Репостов:  19
# Время публикации:  2020-07-13 13:10:31
# ****************************************
#
# Текст:  Продолжаем изучать HTML!
# На очереди еще три базовых тега, которые важно знать: <canvas>...</canvas>, <input> и <select>...</select>. О них читайте в карточках!
#
# #Skillbox_программирование #Учим_HTML
#
# Лайков:  104
# Репостов:  11
# Время публикации:  2020-07-12 15:07:29
# ****************************************
#
# Текст:  Бумага все стерпит!
#
# Примерно так мог бы звучать слоган проекта Infinite Wrap, разработанного студией дизайна из Гонконга BLOW (@blowhongkong). Основатель студии, именитый дизайнер Кен Ло, заметил некоторые недостатки в традиционной оберточной бумаге. Например, то, что отрезанным излишкам уже нельзя найти применение.
#
# Вдохновленный стилем пэчворк, Кен Ло придумал складную и разборную бумагу — для упаковки подарков, изготовления оригами или постеров. От нее можно оторвать фрагмент нужного размера, а остальное сохранить на будущее. Дизайн выстроен таким образом, что все части полотна сочетаются друг с другом.
# Гениально и просто!
#
# #Упаковка_Skillbox #Skillbox_дизайн
#
# Лайков:  73
# Репостов:  5
# Время публикации:  2020-07-11 14:07:43
# ****************************************
#
# Текст:  Онлайн-курсы Skillbox напоминают сериал: каждый раз вы узнаете что-то новое, занятия тоже занимают примерно 40 минут в день, и то, и другое можно смотреть дома на диване.
#
# Но есть и важное отличие: после просмотра сериала вас вряд ли пригласят играть в кино. Зато после наших курсов вы получите востребованную профессию.
#
# Выберите интересующую программу и получите бесплатный доступ к первым модулям курсов на 7 дней. После тестового периода подарим скидку 50%: https://vk.cc/awOA5h
#
# #Анонс_Skillbox
#
# Лайков:  36
# Репостов:  1
# Время публикации:  2020-07-10 18:21:28
# ****************************************
#
# Текст:  Пока вы думали, как собрать средства на реализацию своего проекта, мы собрали для вас топ краудфандинговых площадок. Они не только помогут профинансировать вашу работу, но и покажут, насколько хорошо ее воспринимает аудитория.
# Смотрите подборку в карточках!
#
# #Skillbox_маркетинг #В_закладки_Skillbox
#
# Лайков:  250
# Репостов:  54
# Время публикации:  2020-07-10 14:55:52
# ****************************************
#
# Текст:  Вы каждый день видите 3D-графику, но задумывались ли, она устроена изнутри? Как обычные точки превращаются в изображение, неотличимое от настоящего? Давайте расскажем.
#
# #Статья_Skillbox
#
# Лайков:  59
# Репостов:  6
# Время публикации:  2020-07-09 20:00:28
# ****************************************
#
# Текст:  Пока вы откладываете учебу на завтра, нейросети продолжают осваивать новые навыки. Им больше не чуждо ничто человеческое: они пишут книги, сочиняют музыку, управляют автомобилем, даже предсказывают погоду. Чему еще они успели научиться? Читайте в карточках!
#
# #Skillbox_программирование #В_закладки_Skillbox
#
# Лайков:  102
# Репостов:  5
# Время публикации:  2020-07-09 14:58:10
# ****************************************
#
# Текст:  Ксения Карпова, IT-рекрутёр, рассказывает об алгоритме поиска работы. Четыре шага, чеклист для проверки и советы для сложных ситуаций.
#
# #Статья_Skillbox
#
# Лайков:  68
# Репостов:  4
# Время публикации:  2020-07-08 21:33:10
# ****************************************
#
# Текст:  — После стольких лет?
# — Всегда!
#
# К 20-летию первой публикации «Гарри Поттера» в Литве художница из Вильнюса Екатерина Будрите (@jekaterina_budryte) нарисовала альтернативные обложки ко всем частям истории.
#
# Почти во всех иллюстрациях главный акцент сделан не на самом герое, а на ассоциативных образах, связанных с книгами. Например, обложка к «Узнику Азкабана» изображает маховик времени, дементоров, листья Гремучей ивы, а также сражение Сириуса Блэка и Питера Петтигрю в образах собаки и крысы.
# Завораживает палитра: в этой сдержанности оттенков есть нечто волшебное ⚡️
#
# Похоже, кто-то применил магию вне Хогвартса!
#
# #Skillbox_дизайн #Skillbox_вдохновляет #Иллюстрация_Skillbox
#
# Лайков:  224
# Репостов:  13
# Время публикации:  2020-07-08 15:17:51
# ****************************************
#
# Текст:  Дизайн - это не только линии и заливки. Это ещё и «пустота». И она часто бывает важнее линий! Рассказываем (и показываем), как использовать работать с пустым  пространством в дизайне.
#
# #Статья_Skillbox
#
# Лайков:  78
# Репостов:  18
# Время публикации:  2020-07-07 21:24:52
# ****************************************
#
# Текст:  Уже завтра стартует новый онлайн-проект от Skillbox «Дизайн, философия и киборги»!
# Кандидат философских наук, автор книг и статей о новейшей философии Серж Степанищев проведет лекцию «Требование невозможного: философия и дизайн в XXI веке».
# На первой лекции вы узнаете, что такое хоррор-реализм, ксенонаука и астробиология, на чем строится современная философия дизайна и почему меньше значит больше.
# Подписывайтесь на бесплатный мини-курс и смотрите лекцию в прямом эфире.
#
# Начало 8 июля в 19:00, время московское: https://vk.cc/awI64j
#
# #Skillbox_Дизайн
#
# Лайков:  28
# Репостов:  2
# Время публикации:  2020-07-07 18:36:19
# ****************************************
#
# Текст:  Остановись, мгновенье, ты прекрасно! Особенно в исполнении моушен-дизайнера из Лондона Льюиса Ортона (@lewisorton). В своем экспериментальном проекте Ортон воссоздал момент раскрытия цветочного бутона в формате диджитал-таймлапс.
#
# С помощью инструментария Houdini дизайнер разработал уникальную систему, которая отдельно управляет каждым элементом цветка — от тычинок до лепестков — в течение всего его жизненного цикла.
#
# Включайте видео и смотрите, что из этого вышло.
#
# #Skillbox_Дизайн
#
# Лайков:  144
# Репостов:  13
# Время публикации:  2020-07-07 15:12:50
# ****************************************
#
# Текст:  Полезная шпаргалка по требованиям к рекламным объявлениям «ВКонтакте». Теперь не запутаетесь в количестве знаков и размерах картинок.
#
# #Статья_Skillbox
#
# Лайков:  118
# Репостов:  24
# Время публикации:  2020-07-06 20:00:56
# ****************************************
#
# Текст:  Хотели бы посмотреться в зеркало, которое все превращает в 2D-анимацию?
#
# Теперь есть такая возможность! Сервис Pose Animator в режиме реального времени распознает ваши движения по веб-камере и переносит их на векторного персонажа. Поднимайте руки, кривите рот, танцуйте — нарисованный человечек повторит все за вами.
# Создатели инструмента позаимствовали идею скелетной анимации из компьютерной графики и задействовали результаты распознавания PoseNet и FaceMesh.
#
# Попробуйте, очень занятная вещь: https://vk.cc/awFJDB
#
# #Skillbox_программирование #В_закладки_Skillbox
#
# Лайков:  79
# Репостов:  8
# Время публикации:  2020-07-06 18:37:49
# ****************************************
#
# Текст:  На этой неделе собрали все, что вы так любите. Расскажем, как продвигать бренд в соцсетях, напишем игру на Unity и за три дня создадим мессенджер на Python.
#
# Подключайтесь, ждем вас! Начало всех вебинаров — по московскому времени.
#
# Чтобы не пропустить интересующие вас вебинары, подпишитесь на рассылку. Раз в день или раз в неделю мы рассказываем о предстоящих вебинарах, а за 20 минут до начала присылаем ссылку на участие.
# 👉 https://vk.com/app6051158_-66669811
#
# Если не сможете принять участие в прямом эфире, смотрите в записи в любое удобное время здесь:
# 👉 https://vk.cc/9B4uhq
#
# #Расписание_Skillbox
#
# Лайков:  42
# Репостов:  3
# Время публикации:  2020-07-06 14:14:09
# ****************************************
#
# Текст:  Компания Pentatonic давно известна своим желанием избавить планету от мусора и навсегда решить проблему утилизации отходов.
#
# Они уже создавали стильную офисную мебель из пластиковых и алюминиевых бутылок, стаканы из переработанных дисплеев смартфонов. На очереди совместный проект с музыкантом Фаррелом Уильямсом. В коллаборации они выпустили набор многоразовых столовых приборов, сделанных из CD-дисков и пищевой упаковки.
#
# Удобный футляр с ножом, вилкой, ложкой, палочками и трубочкой можно всегда брать с собой — набор весит как смартфон, всего 175 грамм. Когда приборы изживут себя, их можно вернуть обратно в Pentatonic для очередной переработки.
# Помимо благородной цели продукт отличается и привлекательным дизайном.
#
# #Упаковка_Skillbox #Skillbox_дизайн
#
# Лайков:  377
# Репостов:  13
# Время публикации:  2020-07-05 16:04:07
# ****************************************
#
# Текст:  Мы провели очередной челлендж — на сей раз для учащихся программы «Художник компьютерной графики» и курса «Рекламная графика».
#
# Студенты создавали рекламные иллюстрации для новых вкусов печенья Oreo, используя навыки, полученные на курсе. И вот наши победители: [id444791455|Анастасия Жукова], [id1853210|Антон Вереин] и [id18661064|Анастасия Петрова]. Поздравляем и с радостью делимся их работами! Смотрите иллюстрации ребят и ролики о том, как они создавались, в галерее к посту.
#
# Если и вы хотите прокачать свои навыки, запишитесь на курс Skillbox «Художник компьютерной графики»: https://vk.cc/atjgEp. Учиться новому никогда не поздно 😉
#
# #Студенты_Skillbox #Skillbox_дизайн
#
# Лайков:  126
# Репостов:  6
# Время публикации:  2020-07-04 13:32:30
# ****************************************
#
# Текст:  Представьте: еще нет Инстаграма, про существование Фейсбука и ВКонтакте знают далеко не все, а форумы уже изжили себя. Где делиться своими мыслями?
# Начинающие блогеры 2000-х находили возможности даже в таких условиях. О сервисах, которые были популярны в то время, расскажем в карточках!
#
# #Skillbox_маркетинг #В_закладки_Skillbox
#
# Лайков:  82
# Репостов:  9
# Время публикации:  2020-07-03 14:23:28
# ****************************************
#
# Текст:  Можно ли написать хорошую статью по теме, в которой вы не разбираетесь? Можно, если тщательно поработать с фактурой. Рассказываем, где эту самую фактуру брать и что с ней делать дальше.
#
# #Статья_Skillbox
#
# Лайков:  69
# Репостов:  9
# Время публикации:  2020-07-02 20:00:50
# ****************************************
#
# Текст:  На прошлой неделе в Азии отметили Праздник драконьих лодок — фестиваль, который знаменует наступление летней жары.
# Мы не знаем, как прошло само мероприятие. Но если оно получилось таким же восхитительным, как его видео-анонс, то праздник действительно удался!
#
# Автор ролика — моушен-дизайнер из Сингапура Дебора Вонг. Перед началом работы Вонг составила мудборд из артов и постеров фестиваля прежних лет. На его основе была разработана палитра из пяти теплых оттенков.
#
# Затем Вонг прописала подробный сценарий движения камеры и анимации предметов. И, наконец, реализовала задумку. Благодаря сочетанию 3D-объектов, рукописных элементов, легкого фонового паттерна и продуманной гаммы видео получилось таким завораживающим, что хочется ставить на повтор.
# А какая барабанная партия!
#
# #МоушнSkillbox #Skillboxвдохновляет
#
# Лайков:  157
# Репостов:  7
# Время публикации:  2020-07-02 14:37:56
# ****************************************
#
# Текст:  Цитата: "Создание и защиту репутации нельзя делегировать третьей стороне. Если за вас её формируют клиенты, сотрудники, хейтеры или репутационные агентства — это не ваша репутация. А значит, и не ваш актив."
#
# Хорошая и вдумчивая статья о том, что такое "управление репутацией" на самом деле."
#
# #Статья_Skillbox
#
# Лайков:  55
# Репостов:  6
# Время публикации:  2020-07-01 20:01:31
# ****************************************
#
# Текст:  Подборка бесплатных шрифтов месяца! На очереди акцидентные начертания с кириллицей и латиницей в комплекте. Пополняйте свою коллекцию.
#
# ★ Dulya. Этот необычный шрифт разработал дизайнер из Санкт-Петербурга Виктор Песоцкий (@vviiktoor). Начертание букв основано на классическом почерке, который преподают в школе, но чтобы символы смотрелись интереснее, их пришлось несколько исказить. Поддерживается почти 90 языков, в наборе прописные и строчные буквы: https://vk.cc/awudz7
#
# ★ Engin. Еще одна работа Виктора Песоцкого — шрифт Engin. Острый, футуристический, с нестандартным узором букв и широкими формами, — по мнению Виктора, это шрифт будущего, и именно его будут использовать в далеком 2132 году. Впрочем, зачем так долго ждать — он уже сейчас доступен для скачивания: https://vk.cc/awudAS
#
# ★ Zyablik. Примерно 10-12 часов — именно столько времени понадобилось дизайнеру из Санкт-Петербурга Ивану Пивоварову (@northwesternkingdom), чтобы разработать привлекательный акцидентный шрифт. Если вы ищете оригинальное начертание для постеров, заголовков, брендинга или наружной рекламы — это то, что нужно: https://vk.cc/awudCg
#
# #Шрифты_Skillbox #Skillbox_дизайн
#
# Лайков:  113
# Репостов:  11
# Время публикации:  2020-07-01 14:12:16
# ****************************************
#
# Текст:  А вы задумывались, зачем нужен дизайн? Ну, кроме того, «чтобы красиво». Показываем, как графические дизайнеры делают мир понятнее.
#
# #Статья_Skillbox
#
# Лайков:  84
# Репостов:  14
# Время публикации:  2020-06-30 20:51:28
# ****************************************
#
# Текст:  Какое жаркое начало июля в онлайн-Лектории Skillbox — сразу 4 лекции в первые две недели месяца! Проходите по ссылкам и регистрируйтесь, чтобы посмотреть прямые трансляции.
# Начало эфиров — по московскому времени.
#
# ★ 2 июля, 19:00. Customer Journey Map: мифы и реальность
# Исследователи компании Maratovich&Romanovskaya Дарья Романовская, Максим Маратович и Рудольф Коловертнов покажут, чем с точки зрения бизнеса полезен Customer Journey Map, объяснят, как с его помощью находить точки роста, и предупредят, каких ошибок стоит избегать при его построении: https://vk.cc/awstjH
#
# ★ 3 июля, 19:00. Компонентный подход к дизайну. Кейсы Farfetch
# Principal-дизайнер Farfetch Александр Арцвуни расскажет о компонентном подходе к дизайну на примере своего опыта, поделится интересными кейсами и объяснит, почему principal-дизайнер — это хорошая альтернатива для карьерного роста: https://vk.cc/awstoC
#
# ★ 7 июля, 19:00. Дизайн интерьера PRO: психология клиента. Дизайн-продюсер, президент Союза Дизайнеров и Архитекторов Евгений Тюрин поговорит о том, почему для создания хороших интерьеров нужно знать психологию, научит находить с клиентом общий язык с учетом его ценностей, потребностей и мировоззрения: https://vk.cc/awstCH
#
# ★ 14 июля, 19:00. Как дизайнерам интерьера создавать личный бренд. Бизнес-коуч, эксперт курса Skillbox «Профессия дизайнер интерьеров» и журнала AD Ксения Ульянова проведет лекцию о том, как дизайнерам интерьеров продвигать личный бренд в соцсетях, формировать лояльную аудиторию и привлекать клиентов с помощью контента: https://vk.cc/awstPC
#
# #Лекторий_Skillbox
#
# Лайков:  29
# Репостов:  2
# Время публикации:  2020-06-30 18:33:12
# ****************************************
#
# Текст:  Если вы видите этот пост, значит, вас можно поздравить!
# Сегодня мы отмечаем #SMDay — Всемирный день социальных сетей.
#
# Увы, появились соцсети не так давно, и многие исторические личности не успели оценить всех их плюсов. Давайте восстановим справедливость! Представим, как бы выглядели аккаунты Энди Уорхола, Алана Тьюринга, Дэвида Огилви и Маргарет Тэтчер в популярных социальных сетях. Смотрите в карточках!
#
# Кстати, День соцсетей мог бы стать вашим профессиональным праздником. Зписывайтесь на двухгодичный курс «Профессия SMM-маркетолог» и получите специальность мечты: https://vk.cc/aws313
#
# #Skillbox_маркетинг #В_закладки_Skillbox
#
# Лайков:  68
# Репостов:  1
# Время публикации:  2020-06-30 16:03:47
# ****************************************
#
# Текст:  — Какие три мировых тренда будут актуальны в мобильной разработке на ближайшую пару лет?
# — Реально ли в одиночку создать и вывести на рынок мобильное приложение?
# — Какие ошибки совершают начинающие разработчики?
# — Какие пять принципов нужно помнить мобильным стартащикам?
#
# Об этом — и не только — мы поговорили с руководителем студии AppCraft, Александром Мурзанаевым. Интервью получилось большое и интересное, почитайте.
#
# #Skillbox_Программирование #Статья_Skillbox
#
# Лайков:  38
# Репостов:  1
# Время публикации:  2020-06-29 22:26:24
# ****************************************
#
# Текст:  С нами скучать не приходится — на этой неделе приготовили для вас шесть классных интенсивов 😁 Напишем электронную музыку с нуля вместе с Pixelord'om, нарисуем продающий сайт, научим 50-и секретным приемам для привлечения клиентов — и это только начало!
#
# Подключайтесь, ждем вас! Начало всех вебинаров — по московскому времени.
#
# Чтобы не пропустить интересующие вас вебинары, подпишитесь на рассылку. Раз в день или раз в неделю мы рассказываем о предстоящих вебинарах, а за 20 минут до начала присылаем ссылку на участие.
# 👉 https://vk.com/app6051158_-66669811
#
# Если не сможете принять участие в прямом эфире, смотрите в записи в любое удобное время здесь:
# 👉 https://vk.cc/9B4uhq
#
# #Расписание_Skillbox
#
# Лайков:  39
# Репостов:  1
# Время публикации:  2020-06-29 19:17:18
# ****************************************
#
# Текст:  Знаете ли вы, кто был самым молодым нобелевским лауреатом? А кто сумел получить премию сразу в двух направлениях? А кому пришлось дольше других ждать вручения?
#
# В день основания Фонда Нобеля предлагаем ознакомиться с подборкой фактов о лауреатах. Смотрите в карточках!
#
# Что ж, за дизайн, маркетинг и программирование Нобелевскую премию пока не вручают, но кто знает — вдруг вы станете первым, кто ее получит: https://vk.cc/arylYc
#
# #В_закладки_Skillbox
#
# Лайков:  82
# Репостов:  2
# Время публикации:  2020-06-29 15:22:35
# ****************************************
#
# Текст:  Сегодня свой 49-й день рождения отмечает генеральный и гениальный директор Space X и Tesla Илон Маск.
# Месяц назад его детище SpaceX Crew Dragon стало первым частным пилотируемым космическим кораблем в истории. А знаете ли вы другие проекты современного Тони Старка? Собрали их в карточках.
#
# #В_Закладки_Skillbox
#
# Лайков:  298
# Репостов:  27
# Время публикации:  2020-06-28 13:26:48
# ****************************************
#
# Текст:  Dolby Labs, ведущая компания в области систем обработки звука, звукозаписи и звуковоспроизведения, впервые с 2008 года обновила свой логотип.
#
# Это значит, что у нас новый батл!
#
# В левом углу ринга — старый вариант, где название написано прописными буквами, а обращенные друг к другу буквы «D» помещены в прямоугольник.
#
# В правом углу ринга — новый, более неформальный логотип. В текстовой части из прописных осталась только «D», остальные буквы — строчные. Также двойная «D» в логотипе избавилась от рамки.
#
# Какой вариант лучше? Голосуем и обсуждаем в комментариях!
#
# #Design_Battle_Skillbox #Skillbox_дизайн
#
# Лайков:  41
# Репостов:  0
# Время публикации:  2020-06-27 19:02:46
# ****************************************
#
# Текст:  Встречайте новый онлайн-проект от Skillbox — «Дизайн, философия и киборги»!
#
# В рамках бесплатного курса мы вместе с философом Сержем Степанищевым отправимся на поиски ответов, которые помогут понять:
#
# ⚡️ Существует ли философия дизайна?
#
#  ⚡️ Почему меньше значит больше?
#
# ⚡️  В чем разница между дизайнером, художником и инженером?
#
# Давайте философствовать вместе! Смотрите онлайн-лекции и подпишитесь, чтобы не пропустить выход новых выпусков: https://vk.cc/awiI0T
#
# #анонс_skillbox
#
# Лайков:  58
# Репостов:  8
# Время публикации:  2020-06-26 21:40:20
# ****************************************
#
# Текст:  Решили запустить канал компании в Instagram? Прочитайте наш обзор распространённых ошибок и не совершайте их. Уже запустили? Всё равно прочитайте — и поправьте.
#
# #Статья_Skillbox #Skillbox_Маркетинг
#
# Лайков:  82
# Репостов:  20
# Время публикации:  2020-06-26 21:00:27
# ****************************************
#
# Текст:  Новое — всегда забытое старое.
#
# Об этом напомнило брендинговое агентство из Вьетнама Bratus Agency. Для подарочной упаковки кофе и какао они решили использовать шрифты, которые были популярны в Сайгоне до 1975 года.
#
# Понадобилось целое исследование: участники проекта искали старые письма, документы, книги, рекламу в газетах, журналы, баннеры магазинов — словом, все источники, которые могли дать хоть какую-то информацию о популярных начертаниях.
#
# В итоге они собрали огромную коллекцию шрифтов, но — увы! Ни один из них не отражал в полной мере настроение эпохи. И потому было решено выбрать случайные символы из каждого начертания.
# Что у них получилось — смотрите в нашей карусели.
#
# А для всех, кто считает, что шрифты — это больше, чем просто буквы и символы, у нас есть курс «Шрифт в дизайне», сделанный совместно с Paratype: https://vk.cc/awd7YF
#
# #Skillbox_дизайн
#
# Лайков:  57
# Репостов:  5
# Время публикации:  2020-06-26 13:01:45
# ****************************************
#
# Текст:  У нас не совсем обычный обзор необычной игры.
#
# Автор увидел в игре нечто большее, чем просто "стрелялку" — и поделился мыслями, на которые его эта игра навела. А финальный вывод настолько хорош, что не удержимся и проспойлерим:
#
# "Мы играем в шутеры, потому что хотим спасать людей, быть героями. Но делаем это не для них, а для себя. И чтобы потешить своё эго, мы готовы на всё: использовать химическое оружие, убивать невиновных, уничтожать своих и оставлять за собой горы трупов."
#
# Эта мысль стоит того, чтобы над ней подумать.
#
# #Skillbox_Программирование #Статья_Skillbox
#
# Лайков:  55
# Репостов:  3
# Время публикации:  2020-06-25 21:00:34
# ****************************************
#
# Текст:  Хотите сделать свой подкаст, но не знаете как? Аня Марчук (@quaria), одна из создательниц подкаста «Давай поговорим», рассказала нам, как запустить проект с нуля. О чем нужно подумать заранее, с какими сложностями предстоит столкнуться и как с ними справиться — читайте в карточках!
#
# #В_Закладки_Skillbox
#
# Лайков:  162
# Репостов:  27
# Время публикации:  2020-06-25 18:54:07
# ****************************************
#
# Текст:  Сочиняя игру, не пытайтесь вытрясти последнюю копеечку из игроков за улучшения их персонажей. Мы составили свод правил, которые помогут вам избежать обвинений в жадности.
#
# #Skillbox_Программирование #Статья_Skillbox
#
# Лайков:  41
# Репостов:  10
# Время публикации:  2020-06-24 20:28:14
# ****************************************
#
# Текст:  Знакомьтесь, новая айдентика Badoo.
#
# Один из крупнейших сервисов для знакомств решил напомнить своим визуальным оформлением о ценности отношений и тех теплых чувствах, которые они вызывают.
# Команда дизайнеров MagicLab Design (@magiclab.design) переработала логотип бренда, объединив сердечко и улыбку в одном символе. По словам авторов, это придало ему узнаваемости и оригинальности, добавило нужную эмоциональную ноту.
# Ключевыми деталями новой айдентики стали рукописные элементы, кастомный шрифт и забавные векторные иллюстрации, выполненные в гротескной манере и измененной брендовой палитре.
# Получилось очень харизматично — посмотрите в нашей карусели.
#
# #Айдентика_Skillbox #Skillbox_вдохновляет #Skillbox_дизайн
#
# Лайков:  99
# Репостов:  4
# Время публикации:  2020-06-24 15:10:27
# ****************************************
#
# Текст:  Работать без договора — плохо. Но работать с плохим договором ещё хуже! Читайте советы от практика: что фиксировать в договоре, какие гарантии давать.
#
# #Skillbox_Управление #Статья_Skillbox
#
# Лайков:  102
# Репостов:  26
# Время публикации:  2020-06-23 20:00:01
# ****************************************
#
# Текст:  «Главное в руководстве компанией в эпоху постоянных изменений — внимание к людям».
#
# У эксперта в области оптимизации компаний Джима Хемерлинга есть одна злободневная лекция на TED. Он рассказывает, как управлять большой компанией, когда вокруг все меняется: https://vk.cc/awa3Hp. Мы посмотрели лекцию за вас и сделали по ней небольшой конспект. Читайте карточки.
#
# #В_закладки_Skillbox #Skillbox_управление
#
# Лайков:  98
# Репостов:  13
# Время публикации:  2020-06-23 15:06:32
# ****************************************
#
# Текст:  САНКТ-
# ПЕТЕР
# БУРГ
#
# Еще не забыли логотип культурной столицы, который вызвал резонанс в соцсетях? Похоже, его снова будут менять — глава комитета по развитию туризма Сергей Корнеев заявил: если логотип не будет восприниматься и использоваться, создадут новый.
#
# Давайте тоже пофантазируем и предложим варианты. Присылайте свое творчество в комментариях до 29 июня. Автора самой крутой работы объявим 30 июня, он получит традиционный фирменный мерч от Skillbox.
#
# #Конкурс_Skillbox #Skillbox_дизайн
#
# Лайков:  63
# Репостов:  5
# Время публикации:  2020-06-22 16:00:38
# ****************************************
#
# Текст:  За окном жара, и хочется чего угодно, только не работать 😁 Но давайте немного поднажмем, ведь у нас такие классные вебинары на этой неделе! Расскажем, как запустить собственный бренд одежды, вместе с вами соберем продающего чат-бота и нарисуем дизайн интерьера.
#
# Ждем вас!
#
# Чтобы не пропустить интересующие вас вебинары, подпишитесь на рассылку. Раз в день или раз в неделю мы рассказываем о предстоящих вебинарах, а за 20 минут до начала присылаем ссылку на участие.
# 👉 https://vk.com/app6051158_-66669811
#
# Если не сможете принять участие в прямом эфире, смотрите в записи в любое удобное время здесь:
# 👉 https://vk.cc/9B4uhq
#
# #Расписание_Skillbox
#
# Лайков:  43
# Репостов:  8
# Время публикации:  2020-06-22 14:05:24
# ****************************************
#
# Текст:  Друзья, у нас стартует совместный проект с издательской группой «Альпина»!
#
# В серии онлайн-встреч мы побеседуем с авторами популярных книг — о новом мире и месте человека в нем.
#
# Специалист по креативности Игорь Намаконов, антрополог Станислав Дробышевский, судмедэксперт Алексей Решетун и другие авторитетные спикеры расскажут о глобальных изменениях в политике, экономике и обществе, а также объяснят, как войти в новую реальность с минимальными потерями — моральными и материальными.
#
# Встречи пройдут с 29 июня по 10 июля. Зарегистрируйтесь, чтобы посмотреть их в прямом эфире: https://vk.cc/aw3kjF
#
# #Альпина_Skillbox #Анонс_Skillbox
#
# Лайков:  32
# Репостов:  5
# Время публикации:  2020-06-21 16:00:29
# ****************************************
#
# Текст:  Какая ваша любимая асана для учебы или работы?
# Долго сидеть за столом или лежать с ноутбуком не рекомендуется — это вредно для позвоночника. Потому многие известные компании, такие как Google, Microsoft и HP, включили занятия йогой в свою корпоративную культуру.
# Почему бы и нам не включить? Мы собрали несколько асан, в которые можно войти, не отрываясь от рабочего или учебного процесса. Смотрите в карточках!
#
# #В_Закладки_Skillbox
#
# Лайков:  184
# Репостов:  23
# Время публикации:  2020-06-21 13:01:07
# ****************************************
#
# Текст:  Как выглядит интерьер вашей мечты?
#
# Думаем, среди работ дизайн-студии из Барселоны Reisinger Studio (@reisingerandres) найдется похожий! Авторы отказались от классического представления об интерьере и создали свое видение уюта.
#
# Асимметрия в сочетании с правильными формами, сюрреалистичная мебель, уход от рациональности в планировке помещений, — здесь нет ни намека на повседневность, а потому работы не перестают будоражить фантазию.
#
# Хотите создавать нечто подобное? Пройдите курс Skillbox «Профессия 3D-визуализатор интерьеров»: https://vk.cc/aw3i01
#
# #Skillbox_дизайн
#
# Лайков:  127
# Репостов:  4
# Время публикации:  2020-06-20 18:19:13
# ****************************************
#
# Текст:  Коммьюнити-менеджеру на заметку. Рассказываем, как организовать работу с сообществом — от поиска тех, к которым можно присоединиться, до создания собственного сообщества с нуля.
#
# Родился, жил и умер: как работать с сообществом на разных этапах.
#
# Часть 1: https://vk.cc/aw1sLS
# Часть 2: https://vk.cc/aw1sRQ
#
# #Skillbox_Маркетинг
#
# Лайков:  44
# Репостов:  4
# Время публикации:  2020-06-19 22:00:55
# ****************************************
#
# Текст:  Есть желание стать специалистом по кибербезопасности, но нет опыта в программировании? Мы нашли решение! Skillbox запускает новый большой курс «Специалист по кибербезопасности».
#
# Из чего состоит программа?
# ★ Курс «Веб-верстка и язык запросов SQL» — чтобы знать внутреннее устройство продукта и уметь его защищать.
# ★ Курс «Сеть» — чтобы освоить основы сетевого взаимодействия, получить знания о структуре корпоративных сетей, научиться настраивать и диагностировать сеть в Windows и Linux.
# ★ Курс «Основы шифрования (СКЗИ)» — чтобы изучить поточное и блочное шифрование, кодировки, ключи, цифровые подписи.
# ★ Курс по Python для пентестеров – чтобы не только научиться программировать, но и видеть всю специфику кодирования в программах для пентеста.
# ★ Курс по Bash – чтобы уметь работать в командной строке и оптимизировать процессы.
# ★★★ Три больших курса о системе Linux — чтобы узнать все о самой ОС и ее защите.
# И это еще далеко не все! Остальное – здесь: https://vk.cc/auwmA7
#
# #Skillbox_Программирование
#
# Лайков:  45
# Репостов:  0
# Время публикации:  2020-06-19 16:09:48
# ****************************************
#
# Текст:  В #ДеньНаблюденияЗаОблаками устраиваем мини-соревнование на прокачку фантазии! Делайте фото облаков и дорисовывайте их так, как подскажет воображение.
#
# Делитесь результатами в комментариях, для автора самой креативной работы уже подготовили фирменный мерч 😏 На выполнение задания у вас неделя, дерзайте!
#
# Победителя объявим 26-го июня в комментариях.
#
# #Skillbox_дизайн
#
# Лайков:  51
# Репостов:  2
# Время публикации:  2020-06-19 12:57:51
# ****************************************
#
# Текст:  Влад работал стилистом и хотел открыть свой салон красоты. Но теперь он программист, пилит площадку для владельцев клубов и собирается изучать бекэнд. Ничего себе поворот, да?
# Почитайте, это интересная история.
#
# #Статья_Skillbox
#
# Лайков:  58
# Репостов:  3
# Время публикации:  2020-06-18 20:21:50
# ****************************************
#
# Текст:  Поиграть или поискать работу?
#
# Не выбирайте — совмещайте приятное с полезным! Платформа для поиска работы Буду www.budu.jobs и интернет-издание vc.ru запустили онлайн-выставку вакансий Game of Jobs в формате 8-битной игры.
# И Skillbox тоже в деле! Так что если вы хотите узнать о наших вакансиях, выиграть сертификат на 30 000 рублей на любой курс Skillbox или просто провести время в прикольной онлайн-игре — заходите: https://vk.cc/avY45W
#
# Суть игры проста: управляйте героем, перемещаясь по карте с «замками» компаний. Заходите внутрь замков, общайтесь с чат-ботами и другими игроками и выполняйте миссии. Посетить онлайн-выставку вы можете до 26 июня 😉
#
# И напоследок дадим маленькую подсказку: в замке Skillbox спрятан промокод на скидку 55% на наши курсы 🤫
#
# #Анонс_Skillbox #Game_of_jobs #БудуВSkillbox
#
# Лайков:  53
# Репостов:  5
# Время публикации:  2020-06-18 17:36:50
# ****************************************
#
# Текст:  Как подчеркнуть в тексте нужную эмоцию, если в нашем арсенале только восклицательный и вопросительный знаки? А что делать с иронией, сарказмом и другими нюансами? Веками типографы разрабатывали новые знаки пунктуации. Но они так и не закрепились в нашем письме.
#
# Авторы проекта Progressive Punсtuation собрали целую коллекцию таких знаков в надежде, что они раз и навсегда избавят нас от недопонимания в письменном общении.
# Самые интересные собрали в карточках. Посмотреть полную версию проекта можно здесь: https://progressivepunctuation.com/
#
# #В_закладки_Skillbox #Skillbox_дизайн
#
# Лайков:  220
# Репостов:  29
# Время публикации:  2020-06-18 13:26:03
# ****************************************
#
# Текст:  Как понять, зайдёт идея или не зайдёт? Хороший совет от практика: тестируйте гипотезы с помощью контекстной рекламы. Это быстро, недорого, и поможет уберечься от больших неудач.
#
# #Статья_Skillbox
#
# Лайков:  42
# Репостов:  5
# Время публикации:  2020-06-17 21:37:01
# ****************************************
#
# Текст:  Как вывести салоны красоты из карантина и вернуть их к нормальной работе?
#
# Узнайте на бесплатном интенсиве Skillbox и «Персоны»! Регистрируйтесь для участия по ссылкам и смотрите лекции ведущих российских экспертов beauty-индустрии в прямом эфире.
#
# 22 июня, 19:00. Сила Лидера. Президент и основатель сети имидж-лабораторий «Персона», председатель Ассоциации предпринимателей индустрии красоты Игорь Стоянов расскажет о роли лидера в beauty-индустрии, поделится своей концепцией «Салон — живой организм» и объяснит, как перезапустить работу салона после кризиса: https://vk.cc/avT0Go
#
# 23 июня, 19:00. Новая реальность – новые возможности. Руководитель отдела развития профессионального подразделения L’Oreal по Москве Алексей Бирюков расскажет, почему в текущей ситуации важны надежные поставщики, промо-поддержка салона и онлайн-обучение сотрудников: https://vk.cc/avT0KV
#
# 24 июня, 19:00. Команда мечты. Бизнес-психолог, коуч, партнер «Бизнес-школы Персона», автор проекта «Психология на кухне» Иван Хроменков объяснит, чем персонал отличается от команды, и расскажет, почему люди – самое важное при восстановлении работы салона: https://vk.cc/avT0Pt
#
# 25 июня, 19:00. Финансы. Управляющий партнер «Бизнес-школы Персона», преподаватель курса по финансовому менеджменту Анна Соколова обсудит возможные сценарии в экономике и обществе и расскажет, как салонам красоты распланировать бюджет в текущей ситуации: https://vk.cc/avT0TH
#
# 26 июня, 19:00. Новые клиенты VS Постоянные. Digital-директор управляющей компании «Персона-Менеджмент» Сергей Теймуров и директор «Персона. Развитие и франчайзинг» Виктор Соколов расскажут, на каких клиентах лучше фокусироваться салонам в период восстановления и поделятся личным опытом, как использовать внешние каналы трафика, чат-боты и прямой обзвон клиентской базы: https://vk.cc/avT11a
#
# #Анонс_Skillbox #Skillbox_управление
#
# Лайков:  26
# Репостов:  1
# Время публикации:  2020-06-17 16:00:20
# ****************************************
#
# Текст:  Июнь в самом разгаре, а учеба в Skillbox — тем более!
# На очереди еще две увлекательные онлайн-лекции в нашем Лектории. Выбирайте тему, проходите по ссылке и регистрируйтесь, чтобы посмотреть лекцию в прямом эфире. Начало трансляций — по московскому времени.
#
# ★ 19.06, 19:00. Синтаксис в интерфейсе и как правильно его нарушать.
# Лекцию проведет автор подкаста для UX-писателей «Редач», UX-писатель в Gett и Яндекс.Картах Ира Моторина. Она объяснит, что такое синтаксис интерфейса и какие в нем есть правила, подробно рассмотрит понятие conversational design и объяснит, почему контекст — это самое главное: https://vk.cc/avSQnV
#
# ★ 23.06, 19:00. Зачем дизайнерам собственные проекты.
# Преподаватель курса Skillbox «Управление дизайн-студией», создатель популярных UI-китов Velocity и Deck Роберт Майер расскажет, зачем дизайнерам заниматься личными проектами, поделится историями успеха и вдохновит на новые идеи: https://vk.cc/avSQxk
#
# #Лекторий_Skillbox
#
# Лайков:  31
# Репостов:  2
# Время публикации:  2020-06-16 21:11:28
# ****************************************
#
# Текст:  Хотите поиграться со шрифтами? У нас вышел гайд по стилизации надписей в логотипах — с классными картинками и советами.
# +500 к вдохновению и дизайнерской насмотренности.
#
# #Статья_Skillbox #Skillbox_Дизайн
#
# Лайков:  113
# Репостов:  17
# Время публикации:  2020-06-15 21:45:50
# ****************************************
#
# Текст:  Продолжаем радовать вас новыми крутыми вебинарами! На этой неделе расскажем, как запустить видеомаркетинг в ТикТоке, напишем чат-бота с искуственным интеллектом и проведем 3-дневный интенсив «Сам себе режиссер».
#
# Ждем вас!
#
# Чтобы не пропустить интересующие вас вебинары, подпишитесь на рассылку. Раз в день или раз в неделю мы рассказываем о предстоящих вебинарах, а за 20 минут до начала присылаем ссылку на участие.
# 👉 https://vk.com/app6051158_-66669811
#
# Если не сможете принять участие в прямом эфире, смотрите в записи в любое удобное время здесь:
# 👉 https://vk.cc/9B4uhq
#
# #Расписание_Skillbox
#
# Лайков:  35
# Репостов:  1
# Время публикации:  2020-06-15 20:09:03
# ****************************************
#
# Текст:  Любите устраивать перестановки в комнате? Похоже, вы прирожденный дизайнер интерьеров. Но пожалейте соседей — направьте свою энергию в игры! А мы уже для вас и подборку сделали — смотрите в карточках!
# Но если вы уже наигрались и хотите всерьез заняться делом, запишитесь на наш курс «Профессия Дизайнер интерьеров»: https://vk.cc/avsVYR
#
# #skillbox_дизайн #в_закладки_skillbox
#
# Лайков:  319
# Репостов:  26
# Время публикации:  2020-06-15 17:38:32
# ****************************************
#
# Текст:  Хотите освоить язык программирования? Let’s Go!
#
# Go, или Golang — простой в изучении язык программирования от Google, который отличается чистотой кода, большим количеством библиотек и лаконичным синтаксисом.
#
# Заметьте разницу: спецификация языка Java занимает 750 страниц, Go – 50. Несмотря на свою простоту, Go используется при разработке высокопроизводительных программ и сервисов. Его плюсы уже оценили разработчики Adobe, BBC, IBM, Intel, [club9695053|Wildberries] . Оцените и вы!
#
# Мы запускаем новый курс «Профессия Go-разработчик» — для новичков и опытных программистов. Вот, что вас на нем ждет:
#
# ⚡ Познакомитесь с синтаксисом языка и напишете несколько программ.
# ⚡ Научитесь настраивать JetBrains GoLand, узнаете, что такое breakpoints и stack trace.
# ⚡ Разработаете сложную микросервисную архитектуру приложения.
# ⚡ Освоите бонус-курсы: «Универсальные знания программиста», «Система контроля версий Git», «Английский для IT-специалистов», «Карьера и развитие программиста».
# ⚡ Напишете диплом «Сетевой многопоточный демон».
#
# Помимо знаний выпускники получат двойной бонус в трудоустройстве: помощь центра карьеры Skillbox и возможность попасть на стажировку в Wildberries!
#
# Go: https://vk.cc/avM1sE
#
# #Анонс_курса #Skillbox_программирование
#
# Лайков:  64
# Репостов:  0
# Время публикации:  2020-06-14 15:25:56
# ****************************************
#
# Текст:  От чертежей Леонардо да Винчи до моделей с сенсорным экраном — рассказываем, какой путь прошла швейная машинка. Читайте в карточках!
#
# А если вы хотите научиться шить на швейной машинке и создавать оригинальную одежду, обратите внимание на наш онлайн-курс «Кройка и шитье»: https://vk.cc/avJRHi
#
# #В_Закладки_Skillbox #Skillbox_Дизайн
#
# Лайков:  61
# Репостов:  9
# Время публикации:  2020-06-13 17:58:38
# ****************************************
#
# Текст:  Пилите на досуге свою игрушку и лелеете планы по завоеванию мира? Вот вам пять полезных статей по геймдизу. Почитайте для ускорения мирового господства :)
#
# Почему квесты в играх скучные и как это исправить — https://vk.cc/avHevW
#
# Чем правдоподобные игры отличаются от реалистичных — https://vk.cc/avHfeC
#
# Как сделать игру доступной для людей с нарушениями моторики — https://vk.cc/avHgY9
#
# Как сделать игру доступной для людей с нарушениями слуха и зрения — https://vk.cc/avHghX
#
# Уравниваем шансы: как работает случайность в играх — https://vk.cc/avHhB5
#
# #Skillbox_Программирование
#
# Лайков:  56
# Репостов:  9
# Время публикации:  2020-06-12 19:33:18
# ****************************************
#
# Текст:  Рисовать музыку руками.
#
# Пока вы пытаетесь это представить, мы расскажем об уникальном музыкальном конструкторе Arma App от аудиохудожников из России.
#
# «Augmented Reality Music Act» — так звучит полное название приложения, которое разработали Святослав Иванов (@holyandglory) и Варвара Шилова (@barbara.shilova).
#
# Как оно работает? Открываете приложение для iOS, на экране появляется изображение с фронтальной камеры и сетка с крупными ячейками. Ставите смартфон на устойчивую поверхность, отходите на пару метров и переставляете ладони по разным квадратам сетки. О чудо, вы пишете техно!
#
# В основе приложения — нейросеть, которая распознает жесты: левая рука отвечает за ударные, правая — за игру на синтезаторе. Так ваши движения превращаются в музыку.
#
# Хотите попробовать? Приложение бесплатное: https://vk.cc/avHJCN
#
# #В_Закладки_Skillbox
#
# Лайков:  52
# Репостов:  7
# Время публикации:  2020-06-12 18:09:53
# ****************************************
#
# Текст:  Два месяца российский бизнес прожил в непривычном и экстремальном режиме. Но кое-что из этого режима стоит перенести и в "нормальную" жизнь. Рассказываем, как защищать компанию от инфекций и форс-мажоров.
#
# #Статья_Skillbox
#
# Лайков:  23
# Репостов:  2
# Время публикации:  2020-06-11 21:11:29
# ****************************************
#
# Текст:  Сегодня делимся удивительными иллюстрациями ирландского художника @cathalduane.
#
# Гротеск в сочетании с яркой палитрой создает ощущение иллюзорности, деформирует представление о перспективе и динамике композиции. Заметьте, как во всех работах ярко выражен авторский почерк: это уже не поиск себя, а четко сформированный стиль.
#
# Как бы оценили работы?
#
# #Иллюстрации #Skillbox_дизайн
#
# Лайков:  192
# Репостов:  7
# Время публикации:  2020-06-11 15:54:27
# ****************************************
#
# Текст:  «Союзмультфильму» — 84 года!
# В день рождения студии расскажем о любимых для многих поколений персонажах советской мультипликации, которые получили известность во всем мире.
# Читайте в карточках!
#
# #В_закладки_Skillbox
#
# Лайков:  153
# Репостов:  10
# Время публикации:  2020-06-10 14:13:33
# ****************************************
#
# Текст:  Красота спасет мир, а салоны красоты спасет грамотное управление.
#
# Skillbox и сеть имидж-лабораторий «Персона» запускают бесплатный интенсив «Антикризисное управление салоном красоты».
#
# В серии лекций ведущие российские эксперты beauty-индустрии расскажут, как барбершопам, моностудиям и салонам красоты правильно выйти из карантина, дадут практические советы по антикризисному управлению и поделятся своими взглядами на ситуацию в отрасли.
#
# Главный эксперт интенсива — президент и основатель сети имидж-лабораторий «Персона», председатель Ассоциации предпринимателей индустрии красоты Игорь Стоянов.
#
# Еще один приятный бонус — Skillbox и «Персона» подготовили скидку на курс «Менеджмент в индустрии красоты» для всех участников интенсива. Регистрируйтесь на интенсив по ссылке: https://vk.cc/avAiGo
#
# #Анонс_Skillbox #Skillbox_управление
#
# Лайков:  37
# Репостов:  1
# Время публикации:  2020-06-09 18:38:39
# ****************************************
#
# Текст:  Кассовый разрыв — страшный сон предпринимателя. Страшнее этого только стабильные убытки. Но откуда берётся кассовый разрыв, если по плану всё сходится и каждый клиент окупается?
#
# Рассказываем о трёх типовых сценариях, когда проект вроде бы в плюсе, а денег внезапно нет.
#
# #Статья_Skillbox #Skillbox_маркетинг
#
# Лайков:  42
# Репостов:  4
# Время публикации:  2020-06-08 22:09:34
# ****************************************
#
# Текст:  Хотим поделиться с вами успехами студентов Skillbox, которые стали победителями нашего внутреннего конкурса. Смотрите их работы в галерее к посту. Ребята только начали осваивать 3D-моделирование, поэтому не забудьте похвалить их в комментариях 😏
#
# А если вы сами хотите погрузиться в 3D-моделирование, обратите внимание на наш курс «Профессия 3D-художник»: https://vk.cc/avxqRn
#
# #Студенты_Skillbox #Skillbox_дизайн
#
# Лайков:  82
# Репостов:  1
# Время публикации:  2020-06-08 18:27:39
# ****************************************
#
# Текст:  На этой неделе вас ждет кое-что новенькое. Расскажем основы коммерческой фотографии и покажем пару лайфхаков, научим писать эффективные тексты для лендинга и познакомим с языками программирования.
#
# Ждем вас!
#
# Чтобы не пропустить интересующие вас вебинары, подпишитесь на рассылку. Раз в день или раз в неделю мы рассказываем о предстоящих вебинарах, а за 20 минут до начала присылаем ссылку на участие.
# 👉 https://vk.com/app6051158_-66669811
#
# Если не сможете принять участие в прямом эфире, смотрите в записи в любое удобное время здесь:
# 👉 https://vk.cc/9B4uhq
#
# #Расписание_Skillbox
#
# Лайков:  55
# Репостов:  5
# Время публикации:  2020-06-08 16:45:15
# ****************************************
#
# Текст:  Ёлки-лапки!
#
# Вы знаете, в каких языках используются кавычки-ёлочки? Где они бывают одинарными или направленными внутрь? Почему обе пары кавычек-лапок иногда пишутся вверху строки?
#
# Журнал Type.today (@type.today) собрал целый справочник по кавычкам. Материал оценят не только шрифтовые дизайнеры: https://type.today/ru/journal/quotes
# Основное из этого справочника собрали в наших традиционных карточках 🙂
#
# #В_Закладки_Skillbox
#
# Лайков:  267
# Репостов:  33
# Время публикации:  2020-06-07 17:26:59
# ****************************************
#
# Текст:  Как описать шведский дизайн в трех словах? Минимализм, простота, функциональность.
#
# В #ДеньШвеции расскажем о культовых предметах интерьера, которые прославили шведский дизайн на весь мир. Читайте в карточках!
# А если вы тоже мечтаете внести свою лепту в создание идеального дома, запишитесь на курс «Профессия дизайнер интерьеров»: https://vk.cc/avsVYR
#
# #Skillbox_Дизайн
#
# Лайков:  125
# Репостов:  8
# Время публикации:  2020-06-06 18:31:34
# ****************************************
#
# Текст:  Хорошо работать на растущих рынках — конкурентов нет, клиенты готовы в очередях стоять и переплачивать втрое... А когда рынок перенасыщен или вообще падает? Рассказываем, что можно сделать кроме бесконечных скидок.
#
# #Статья_Skillbox #Skillbox_маркетинг
#
# Лайков:  50
# Репостов:  7
# Время публикации:  2020-06-05 19:20:07
# ****************************************
#
# Текст:  Как самоизоляция изменила нашу жизнь? Словами это выразить непросто, а вот дизайном — очень доходчиво!
#
# Художники, разработчики и дизайнеры со всего мира создали совместный проект isolation_is (@isolation_is) — сервис с коллекцией интерактивных открыток.
#
# Интерактивных. Открыток. Это как? Очень просто! Заходите на сайт, выбираете открытку, просматриваете и делитесь ей со своим другом, родственником, знакомым — с кем угодно, кому хотите поднять настроение.
#
# Каждая открытка — это своеобразная сатира на перемены в обществе. Внизу есть тумблер «до/после». Достаточно нажать на него, чтобы ощутить тот культурный сдвиг, который произошел в последнее время. Например, в одном интерактиве нужно уворачиваться от летящих в ваш курсор шариков. Но стоит нажать на «после», как шарики начинают его избегать.
#
# Попробуйте сами: https://isolation.is/
#
# #В_закладки_Skillbox #Skillbox_программирование #Skillbox_дизайн
#
# Лайков:  56
# Репостов:  12
# Время публикации:  2020-06-05 14:37:28
# ****************************************
#
# Текст:  — Кем работаешь?
# — Код пишу.
# — Похоже, ты плохой программист...
#
# Это, конечно, шутка. Но давайте разберёмся, почему «писать код» не означает «быть программистом». И почему кода нужно писать как можно меньше.
#
# #Статья_Skillbox
#
# Лайков:  83
# Репостов:  9
# Время публикации:  2020-06-04 21:18:41
# ****************************************
#
# Текст:  Новое упражнение на прокачку креативности!
# Включите воображение: представьте, что появилась соцсеть только для программистов — что-то среднее между Хабром и Вконтакте. Чтобы в ней зарегистрироваться, нужно самостоятельно написать код страницы и сверстать профиль — так модерация поймет, что вы и правда разработчик.
#
# А теперь задача: придумайте название и слоган для этой соцсети. Свои варианты пишите в комментариях.
#
# Через неделю выберем самый креативный ответ и подарим его автору фирменный комплект мерча! Победителя объявим в комментариях.
#
# #Качаем_креатив #Skillbox_маркетинг
#
# Лайков:  43
# Репостов:  5
# Время публикации:  2020-06-04 13:51:03
# ****************************************
#
# Текст:  Открываем летний сезон в Лектории Skillbox!
#
# Ловите две лекции на первую половину июня: по программированию и управлению. Выбирайте интересующую тему, проходите по ссылке и регистрируйтесь, чтобы посмотреть прямую трансляцию. Начало — по московскому времени.
#
# 10 июня, 19:00. Команда: значение, мотивация и работа на удаленке. Руководитель по политике контактов «МегаФона» Ксения Корепанова проведет онлайн-лекцию о том, с чего начинается команда, как поддержать командный дух в режиме онлайн и как помочь сотрудникам расти и развиваться: https://vk.cc/av3dgQ
#
# 16 июня, 19:00. Быстрая подготовка окружений для хакатонов и геймджемов. Старший разработчик платформы бизнес-сервисов «МегаФона» Антон Гладышев расскажет о функциональных возможностях Ansible-плейбуков, научит при помощи Ansible устанавливать ПО и настраивать простую интеграцию между конфигурируемыми и Git-серверами: https://vk.cc/av3ct2
#
# #Лекторий_Skillbox
#
# Лайков:  31
# Репостов:  4
# Время публикации:  2020-06-03 21:55:03
# ****************************************
#
# Текст:  «Сорри, думал, что вчера был выходной»
# «Температура 37 и 1, не хочу никого заразить»
# «Ключи упали в шахту лифта, не ждите»
#
# А какие отмазки для прогула придумывали вы 😁?
#
# В #ДеньПрогульщика предлагаем вспомнить свои лучшие отговорки, чтобы сбежать пораньше с урока, опоздать на пару или не прийти на работу. Делитесь историями в комментариях!
#
# И как удобно, что курсы Skillbox можно не прогуливать — все занятия онлайн. Учитесь, когда хочется: https://vk.cc/arylYc
#
# #Вам_слово_Skillbox
#
# Лайков:  26
# Репостов:  1
# Время публикации:  2020-06-03 14:40:38
# ****************************************
#
# Текст:  Хотите точную трёхмерную модель самого себя? Это уже не фантастика. Мы сделали подборку самых крутых 3D-разработок за последний год — и они правда крутые.
#
# #Статья_Skillbox
#
# Лайков:  45
# Репостов:  5
# Время публикации:  2020-06-02 21:10:48
# ****************************************
#
# Текст:  Наши коллеги и партнеры Red Collar везут в Воронеж одну из самых значимых digital-премий в мире — кубок The Webby Awards!  Для тех, кто не в курсе — это «Оскар» в сфере дизайна.
#
# Их эко-сайт «Спасти китов» признан лучшим по мнению международной академии цифровых искусств и наук IADAS. Оцените и вы: https://save-whales.com/. Горячо поздравляем команду с триумфом и желаем новых громких побед на мировой арене.
#
# И как нельзя кстати: у нас с чемпионами есть совместный экспресс-курс «Дизайнер промосайтов» — учитесь у лучших: https://vk.cc/auYMSW
#
# #Новости_Skillbox
#
# Лайков:  93
# Репостов:  3
# Время публикации:  2020-06-02 15:47:51
# ****************************************
#
# Текст:  Питера Друкера называют отцом современного менеджмента — а ведь он даже не был менеджером! Объясняем в карточках, кто это вообще такой и что же он сделал в далёком 1946 году, что это до сих пор в вузах изучают.
#
# #Статья_Skillbox
#
# Лайков:  60
# Репостов:  8
# Время публикации:  2020-06-01 22:00:50
# ****************************************
#
# Текст:  С первым днем лета, друзья! На этой неделе приготовили много жарких интенсивов😏 Научим вас 50-ти секретным приемам для привлечения клиентов, расскажем, как перестать бояться и полюбить DevOps, и вместе с вами нарисуем продающий сайт.
#
# Ждем вас!
#
# Чтобы не пропустить интересующие вас вебинары, подпишитесь на рассылку. Раз в день или раз в неделю мы рассказываем о предстоящих вебинарах, а за 20 минут до начала присылаем ссылку на участие.
# 👉 https://vk.com/app6051158_-66669811
#
# Если не сможете принять участие в прямом эфире, смотрите в записи в любое удобное время здесь:
# 👉 https://vk.cc/9B4uhq
#
# #Расписание_Skillbox
#
# Лайков:  55
# Репостов:  2
# Время публикации:  2020-06-01 20:54:29
# ****************************************
#
# Текст:  Писать код силой мысли, создавать крутой моушен-дизайн за несколько секунд, генерировать по сотне креативных идей в день. А какую суперспособность хотели бы вы?
#
# У сегодняшнего именинника Супермена их было немало: непробиваемость, суперсила, умение летать и еще с десяток. Как и костюмов. Мы привыкли, что это красный плащ, ромб на груди с буквой S и синие штаны. А что насчет дизайна?
#
# Предлагаем проследить эволюцию костюмов Супермена и других персонажей DC в карточках!
#
# А если хотели бы сами рисовать таких персонажей, начните с нашего курса «Скетчинг для дизайнеров»: https://vk.cc/auVvhq
#
# #В_Закладки_skillbox #Skillbox_дизайн
#
# Лайков:  66
# Репостов:  0
# Время публикации:  2020-06-01 14:35:12
# ****************************************
#
# Текст:  Готовы продолжить изучать HTML? Тогда ловите новый комплект тегов!
#
# Пишите в комментариях, если хотите чаще видеть эту рубрику.
# А пока смотрите карточки!
#
# #Учим_HTML #Skillbox_программирование
#
# Лайков:  252
# Репостов:  33
# Время публикации:  2020-05-31 14:22:41
# ****************************************

# %%
# Преобразуем выше полученные данные в датафрейм 
import pandas as pd
df = pd.DataFrame(dict)
pd.options.display.max_colwidth = 200
df.T.sort_values(['likes', 'reposts'], ascending=[False, False]).set_index('time').sort_index()
# Out:
#                                                                                                                                                                                                                         text  \
# time
# 2020-05-31 14:22:41    Готовы продолжить изучать HTML? Тогда ловите новый комплект тегов!\n\nПишите в комментариях, если хотите чаще видеть эту рубрику.\nА пока смотрите карточки!\n\n#Учим_HTML #Skillbox_программирование
# 2020-06-01 14:35:12  Писать код силой мысли, создавать крутой моушен-дизайн за несколько секунд, генерировать по сотне креативных идей в день. А какую суперспособность хотели бы вы?\n\nУ сегодняшнего именинника Суперм...
# 2020-06-01 20:54:29  С первым днем лета, друзья! На этой неделе приготовили много жарких интенсивов😏 Научим вас 50-ти секретным приемам для привлечения клиентов, расскажем, как перестать бояться и полюбить DevOps, и в...
# 2020-06-01 22:00:50  Питера Друкера называют отцом современного менеджмента — а ведь он даже не был менеджером! Объясняем в карточках, кто это вообще такой и что же он сделал в далёком 1946 году, что это до сих пор в ...
# 2020-06-02 15:47:51  Наши коллеги и партнеры Red Collar везут в Воронеж одну из самых значимых digital-премий в мире — кубок The Webby Awards!  Для тех, кто не в курсе — это «Оскар» в сфере дизайна. \n\nИх эко-сайт «С...
# ...                                                                                                                                                                                                                      ...
# 2020-07-20 17:12:16  Готовы к новым знаниям? Неделя будет очень интенсивной! Мы расскажем о креативе в SMM, сделаем анимированный ролик, разработаем чат-бота с искусственным интеллектом, научимся поднимать конверсию л...
# 2020-07-20 20:28:34                                                     Полагаете, что “свободные” программы - это всегда бесплатно, с открытым кодом, и, в основном, для начинающих? Ничего подобного. \n\n#Статья_Skillbox
# 2020-07-21 13:13:17  Тренировка для дизайнеров!\n\nМы подготовили плакат, в котором намеренной допустили много ошибок в дизайне. Ваша задача — найти их и объяснить в комментариях, что не так. Вечером опубликуем список...
# 2020-07-21 17:06:25  Ждете новую лекцию цикла «Дизайн, философия и киборги»? \n\nСпешим обрадовать: она пройдет уже 22 июля в 19:00! \nСерж Степанищев расскажет о творчестве американского скульптора, арт-критика, осно...
# 2020-07-21 19:50:14                                                                                                Этими инструментами можно создать сайт своими руками, без дизайна и программирования.\n\n#Статья_Skillbox
#
#                     likes reposts
# time
# 2020-05-31 14:22:41   252      33
# 2020-06-01 14:35:12    66       0
# 2020-06-01 20:54:29    55       2
# 2020-06-01 22:00:50    60       8
# 2020-06-02 15:47:51    93       3
# ...                   ...     ...
# 2020-07-20 17:12:16    29       1
# 2020-07-20 20:28:34    15       1
# 2020-07-21 13:13:17    27       2
# 2020-07-21 17:06:25     6       1
# 2020-07-21 19:50:14    20       0
#
# [100 rows x 3 columns]

# %%
# Сортируем по данные по возрастанию, и удаляем пустые значения. 
df = df.T
df = df.dropna()
df[df.likes > df.likes.median()].sort_values('likes', ascending=False)
# Out:
#                                                                                                                                                                                                        text  \
# 34  Компания Pentatonic давно известна своим желанием избавить планету от мусора и навсегда решить проблему утилизации отходов.\n\nОни уже создавали стильную офисную мебель из пластиковых и алюминиевы...
# 74  Любите устраивать перестановки в комнате? Похоже, вы прирожденный дизайнер интерьеров. Но пожалейте соседей — направьте свою энергию в игры! А мы уже для вас и подборку сделали — смотрите в карточ...
# 47  Сегодня свой 49-й день рождения отмечает генеральный и гениальный директор Space X и Tesla Илон Маск. \nМесяц назад его детище SpaceX Crew Dragon стало первым частным пилотируемым космическим кора...
# 86  Ёлки-лапки!\n\nВы знаете, в каких языках используются кавычки-ёлочки? Где они бывают одинарными или направленными внутрь? Почему обе пары кавычек-лапок иногда пишутся вверху строки?\n\nЖурнал Type...
# 99    Готовы продолжить изучать HTML? Тогда ловите новый комплект тегов!\n\nПишите в комментариях, если хотите чаще видеть эту рубрику.\nА пока смотрите карточки!\n\n#Учим_HTML #Skillbox_программирование
# 23  Пока вы думали, как собрать средства на реализацию своего проекта, мы собрали для вас топ краудфандинговых площадок. Они не только помогут профинансировать вашу работу, но и покажут, насколько хор...
# 27  — После стольких лет?\n— Всегда!\n\nК 20-летию первой публикации «Гарри Поттера» в Литве художница из Вильнюса Екатерина Будрите (@jekaterina_budryte) нарисовала альтернативные обложки ко всем час...
# 68  Как подчеркнуть в тексте нужную эмоцию, если в нашем арсенале только восклицательный и вопросительный знаки? А что делать с иронией, сарказмом и другими нюансами? Веками типографы разрабатывали но...
# 80  Сегодня делимся удивительными иллюстрациями ирландского художника @cathalduane. \n\nГротеск в сочетании с яркой палитрой создает ощущение иллюзорности, деформирует представление о перспективе и ди...
# 61  Какая ваша любимая асана для учебы или работы?\nДолго сидеть за столом или лежать с ноутбуком не рекомендуется — это вредно для позвоночника. Потому многие известные компании, такие как Google, Mi...
# 6   В программировании самое главное — практика. Но и качественная теория точно не помешает.\nАвтор курса Skillbox «Профессия Java-разработчик» Даниил Пилипенко и тимлид продюсеров курсов по программи...
# 53  Хотите сделать свой подкаст, но не знаете как? Аня Марчук (@quaria), одна из создательниц подкаста «Давай поговорим», рассказала нам, как запустить проект с нуля. О чем нужно подумать заранее, с к...
# 38  На прошлой неделе в Азии отметили Праздник драконьих лодок — фестиваль, который знаменует наступление летней жары.\nМы не знаем, как прошло само мероприятие. Но если оно получилось таким же восхит...
# 81  «Союзмультфильму» — 84 года!\nВ день рождения студии расскажем о любимых для многих поколений персонажах советской мультипликации, которые получили известность во всем мире.\nЧитайте в карточках!\...
# 30  Остановись, мгновенье, ты прекрасно! Особенно в исполнении моушен-дизайнера из Лондона Льюиса Ортона (@lewisorton). В своем экспериментальном проекте Ортон воссоздал момент раскрытия цветочного бу...
# 9   С Днем эмоджи!\n\nБез них непросто выразить в тексте нужные эмоции, передать настроение или описать ситуацию. Когда не хватает слов, на помощь приходят они — эмоджи на все случаи жизни.\n\nСейчас ...
# 19  В дизайне помогает не только насмотренность, но и «наслушанность». Расширяйте свой профессиональный кругозор, не отрываясь от повседневных дел, — включайте дизайнерские подкасты и погружайтесь в т...
# 62  Как выглядит интерьер вашей мечты?\n\nДумаем, среди работ дизайн-студии из Барселоны Reisinger Studio (@reisingerandres) найдется похожий! Авторы отказались от классического представления об интер...
# 35  Мы провели очередной челлендж — на сей раз для учащихся программы «Художник компьютерной графики» и курса «Рекламная графика».\n\nСтуденты создавали рекламные иллюстрации для новых вкусов печенья ...
# 87  Как описать шведский дизайн в трех словах? Минимализм, простота, функциональность. \n\nВ #ДеньШвеции расскажем о культовых предметах интерьера, которые прославили шведский дизайн на весь мир. Чита...
# 31                                                Полезная шпаргалка по требованиям к рекламным объявлениям «ВКонтакте». Теперь не запутаетесь в количестве знаков и размерах картинок.\n\n#Статья_Skillbox
# 72  Хотите поиграться со шрифтами? У нас вышел гайд по стилизации надписей в логотипах — с классными картинками и советами. \n+500 к вдохновению и дизайнерской насмотренности.\n\n#Статья_Skillbox #Ski...
# 40  Подборка бесплатных шрифтов месяца! На очереди акцидентные начертания с кириллицей и латиницей в комплекте. Пополняйте свою коллекцию.\n\n★ Dulya. Этот необычный шрифт разработал дизайнер из Санкт...
# 20  Продолжаем изучать HTML!\nНа очереди еще три базовых тега, которые важно знать: <canvas>...</canvas>, <input> и <select>...</select>. О них читайте в карточках!\n\n#Skillbox_программирование #Учим...
# 5   У шахмат много плюсов: они прокачивают логику и стратегическое мышление, учат нестандартно мыслить, побеждать и принимать поражение с достоинством.\n\nСловом, игра полезна для студентов всех напра...
# 25  Пока вы откладываете учебу на завтра, нейросети продолжают осваивать новые навыки. Им больше не чуждо ничто человеческое: они пишут книги, сочиняют музыку, управляют автомобилем, даже предсказываю...
# 56          Работать без договора — плохо. Но работать с плохим договором ещё хуже! Читайте советы от практика: что фиксировать в договоре, какие гарантии давать.\n\n#Skillbox_Управление #Статья_Skillbox
# 55  Знакомьтесь, новая айдентика Badoo.\n\nОдин из крупнейших сервисов для знакомств решил напомнить своим визуальным оформлением о ценности отношений и тех теплых чувствах, которые они вызывают.\nКом...
# 57  «Главное в руководстве компанией в эпоху постоянных изменений — внимание к людям».\n\nУ эксперта в области оптимизации компаний Джима Хемерлинга есть одна злободневная лекция на TED. Он рассказыва...
# 95  Наши коллеги и партнеры Red Collar везут в Воронеж одну из самых значимых digital-премий в мире — кубок The Webby Awards!  Для тех, кто не в курсе — это «Оскар» в сфере дизайна. \n\nИх эко-сайт «С...
# 41                                                   А вы задумывались, зачем нужен дизайн? Ну, кроме того, «чтобы красиво». Показываем, как графические дизайнеры делают мир понятнее.\n\n#Статья_Skillbox
# 90  — Кем работаешь?\n— Код пишу.\n— Похоже, ты плохой программист... \n\nЭто, конечно, шутка. Но давайте разберёмся, почему «писать код» не означает «быть программистом». И почему кода нужно писать к...
# 84  Хотим поделиться с вами успехами студентов Skillbox, которые стали победителями нашего внутреннего конкурса. Смотрите их работы в галерее к посту. Ребята только начали осваивать 3D-моделирование, ...
# 46  Знаете ли вы, кто был самым молодым нобелевским лауреатом? А кто сумел получить премию сразу в двух направлениях? А кому пришлось дольше других ждать вручения? \n \nВ день основания Фонда Нобеля п...
# 36  Представьте: еще нет Инстаграма, про существование Фейсбука и ВКонтакте знают далеко не все, а форумы уже изжили себя. Где делиться своими мыслями?\nНачинающие блогеры 2000-х находили возможности ...
# 50  Решили запустить канал компании в Instagram? Прочитайте наш обзор распространённых ошибок и не совершайте их. Уже запустили? Всё равно прочитайте — и поправьте.\n\n#Статья_Skillbox #Skillbox_Марке...
# 32  Хотели бы посмотреться в зеркало, которое все превращает в 2D-анимацию?\n\nТеперь есть такая возможность! Сервис Pose Animator в режиме реального времени распознает ваши движения по веб-камере и п...
# 28  Дизайн - это не только линии и заливки. Это ещё и «пустота». И она часто бывает важнее линий! Рассказываем (и показываем), как использовать работать с пустым  пространством в дизайне.\n\n#Статья_S...
# 21  Бумага все стерпит!\n\nПримерно так мог бы звучать слоган проекта Infinite Wrap, разработанного студией дизайна из Гонконга BLOW (@blowhongkong). Основатель студии, именитый дизайнер Кен Ло, замет...
# 12                                                                                                  Рассказываем о разных способах сделать хороший скриншот - на компьютере и телефоне.\n\n#Статья_Skillbox
# 8                                      Мы сделали гид по профессии копирайтера: рассказываем, что нужно уметь и как этому научиться, чтобы зарабатывать от 50 до 90 тыс. руб. в месяц. \n\n#Статья_Skillbox
# 37  Можно ли написать хорошую статью по теме, в которой вы не разбираетесь? Можно, если тщательно поработать с фактурой. Рассказываем, где эту самую фактуру брать и что с ней делать дальше.\n\n#Статья...
# 26                                              Ксения Карпова, IT-рекрутёр, рассказывает об алгоритме поиска работы. Четыре шага, чеклист для проверки и советы для сложных ситуаций. \n\n#Статья_Skillbox
# 43  Если вы видите этот пост, значит, вас можно поздравить! \nСегодня мы отмечаем #SMDay — Всемирный день социальных сетей. \n \nУвы, появились соцсети не так давно, и многие исторические личности не ...
# 98  Писать код силой мысли, создавать крутой моушен-дизайн за несколько секунд, генерировать по сотне креативных идей в день. А какую суперспособность хотели бы вы?\n\nУ сегодняшнего именинника Суперм...
# 75  Хотите освоить язык программирования? Let’s Go!\n\nGo, или Golang — простой в изучении язык программирования от Google, который отличается чистотой кода, большим количеством библиотек и лаконичным...
# 58  САНКТ-\nПЕТЕР\nБУРГ\n\nЕще не забыли логотип культурной столицы, который вызвал резонанс в соцсетях? Похоже, его снова будут менять — глава комитета по развитию туризма Сергей Корнеев заявил: если...
# 17                                                              “SMM-щик - это тот, кто пишет посты за деньги”. Так думают многие, но нет. Рассказываем, за что платят SMM-специалисту.\n\n#Статья_Skillbox
# 76  От чертежей Леонардо да Винчи до моделей с сенсорным экраном — рассказываем, какой путь прошла швейная машинка. Читайте в карточках! \n\nА если вы хотите научиться шить на швейной машинке и создав...
# 96  Питера Друкера называют отцом современного менеджмента — а ведь он даже не был менеджером! Объясняем в карточках, кто это вообще такой и что же он сделал в далёком 1946 году, что это до сих пор в ...
#
#    likes reposts                 time
# 34   377      13  2020-07-05 16:04:07
# 74   319      26  2020-06-15 17:38:32
# 47   298      27  2020-06-28 13:26:48
# 86   267      33  2020-06-07 17:26:59
# 99   252      33  2020-05-31 14:22:41
# 23   250      54  2020-07-10 14:55:52
# 27   224      13  2020-07-08 15:17:51
# 68   220      29  2020-06-18 13:26:03
# 80   192       7  2020-06-11 15:54:27
# 61   184      23  2020-06-21 13:01:07
# 6    177      31  2020-07-19 13:09:10
# 53   162      27  2020-06-25 18:54:07
# 38   157       7  2020-07-02 14:37:56
# 81   153      10  2020-06-10 14:13:33
# 30   144      13  2020-07-07 15:12:50
# 9    135      16  2020-07-17 14:56:09
# 19   129      19  2020-07-13 13:10:31
# 62   127       4  2020-06-20 18:19:13
# 35   126       6  2020-07-04 13:32:30
# 87   125       8  2020-06-06 18:31:34
# 31   118      24  2020-07-06 20:00:56
# 72   113      17  2020-06-15 21:45:50
# 40   113      11  2020-07-01 14:12:16
# 20   104      11  2020-07-12 15:07:29
# 5    103      16  2020-07-20 13:24:25
# 25   102       5  2020-07-09 14:58:10
# 56   102      26  2020-06-23 20:00:01
# 55    99       4  2020-06-24 15:10:27
# 57    98      13  2020-06-23 15:06:32
# 95    93       3  2020-06-02 15:47:51
# 41    84      14  2020-06-30 20:51:28
# 90    83       9  2020-06-04 21:18:41
# 84    82       1  2020-06-08 18:27:39
# 46    82       2  2020-06-29 15:22:35
# 36    82       9  2020-07-03 14:23:28
# 50    82      20  2020-06-26 21:00:27
# 32    79       8  2020-07-06 18:37:49
# 28    78      18  2020-07-07 21:24:52
# 21    73       5  2020-07-11 14:07:43
# 12    69      11  2020-07-15 21:11:14
# 8     69       4  2020-07-17 20:00:11
# 37    69       9  2020-07-02 20:00:50
# 26    68       4  2020-07-08 21:33:10
# 43    68       1  2020-06-30 16:03:47
# 98    66       0  2020-06-01 14:35:12
# 75    64       0  2020-06-14 15:25:56
# 58    63       5  2020-06-22 16:00:38
# 17    62       7  2020-07-13 22:02:47
# 76    61       9  2020-06-13 17:58:38
# 96    60       8  2020-06-01 22:00:50

# %% [markdown]
# ## Вывод: ##
#
# ## Как видно выше из таблице, в топ 3 попали 3 поста: ##
# ## 1. 1 почетное место, занял пост про экологию: "Компания Pentatonic давно известна своим желанием избавить планету от мусора и навсегда решить проблему утилизации отходов." ##
# Даннй пост лайкнули 377 пользователей группы, поделились постом 33 участника группы. На текущий момент многих волнует данная проблема, поэтому данная тема очень поплярна во всем мире.
# ## 2. 2 место по популярности  занял пост по дизайну:"Любите устраивать перестановки в комнате? Похоже, вы прирожденный дизайнер интерьеров. Но пожалейте соседей — направьте свою энергию в игры!" ##
# Дизайн так и не потерял своей популярности, курсы по дизайну очень популярные среди пользователей. Данный пост лайкнули 319 пользователей группы, поделились постом 26 учасников группы.
# ## 3. 3 место занял пост про космос: Сегодня свой 49-й день рождения отмечает генеральный и гениальный директор Space X и Tesla Илон Маск. ##
# Данное событие действительно взарволо мир, 1 частный космический корабль был запушен в космос. Данный пост лайкнули 298 пользователей группы, поделились постом 27 учасников группы.

# %%
# Собираем данные по хештегам из постов
import re
pattern = r'#\w*'

list_news = ', '.join(map(str, df.text.values))
hashtags = re.findall(pattern, list_news)
# Создаю сортированный список уникальных хештегов 
unique_hashtags = sorted(list(set(hashtags)))[1:]

# %%
# Собираем сводную статкистику по хештегам, минимальное, максимальное, среднее, медианное значения лайков и репостов.
hashtag_dict = {}
for i in unique_hashtags:
    hashtag_dict[i] = {'post_count':df[df.text.str.contains(i, regex=False)].likes.count(),
                       
                       'likes_min':df[df.text.str.contains(i, regex=False)].likes.min(),
                       'reposts_min':df[df.text.str.contains(i, regex=False)].reposts.min(),
                       
                       'likes_max':df[df.text.str.contains(i, regex=False)].likes.max(),
                       'reposts_max':df[df.text.str.contains(i, regex=False)].reposts.max(),

                       
                       'likes_mean':df[df.text.str.contains(i, regex=False)].likes.mean(),
                       'reposts_mean':df[df.text.str.contains(i, regex=False)].reposts.mean(),
                       
                       'likes_median':df[df.text.str.contains(i, regex=False)].likes.median(),
                       'reposts_median':df[df.text.str.contains(i, regex=False)].reposts.median(),
                     
}

# %%
hashtag_dict
# Out:
# {'#Game_of_jobs': {'post_count': 1,
#   'likes_min': 53,
#   'reposts_min': 5,
#   'likes_max': 53,
#   'reposts_max': 5,
#   'likes_mean': 53.0,
#   'reposts_mean': 5.0,
#   'likes_median': 53.0,
#   'reposts_median': 5.0},
#  '#SMDay': {'post_count': 1,
#   'likes_min': 68,
#   'reposts_min': 1,
#   'likes_max': 68,
#   'reposts_max': 1,
#   'likes_mean': 68.0,
#   'reposts_mean': 1.0,
#   'likes_median': 68.0,
#   'reposts_median': 1.0},
#  '#Skillbox_Дизайн': {'post_count': 8,
#   'likes_min': 6,
#   'reposts_min': 1,
#   'likes_max': 144,
#   'reposts_max': 19,
#   'likes_mean': 78.375,
#   'reposts_mean': 8.875,
#   'likes_median': 87.0,
#   'reposts_median': 8.5},
#  '#Skillbox_Маркетинг': {'post_count': 2,
#   'likes_min': 44,
#   'reposts_min': 4,
#   'likes_max': 82,
#   'reposts_max': 20,
#   'likes_mean': 63.0,
#   'reposts_mean': 12.0,
#   'likes_median': 63.0,
#   'reposts_median': 12.0},
#  '#Skillbox_Программирование': {'post_count': 5,
#   'likes_min': 38,
#   'reposts_min': 0,
#   'likes_max': 56,
#   'reposts_max': 10,
#   'likes_mean': 47.0,
#   'reposts_mean': 4.6,
#   'likes_median': 45.0,
#   'reposts_median': 3.0},
#  '#Skillbox_Управление': {'post_count': 1,
#   'likes_min': 102,
#   'reposts_min': 26,
#   'likes_max': 102,
#   'reposts_max': 26,
#   'likes_mean': 102.0,
#   'reposts_mean': 26.0,
#   'likes_median': 102.0,
#   'reposts_median': 26.0},
#  '#Skillbox_вдохновляет': {'post_count': 2,
#   'likes_min': 99,
#   'reposts_min': 4,
#   'likes_max': 224,
#   'reposts_max': 13,
#   'likes_mean': 161.5,
#   'reposts_mean': 8.5,
#   'likes_median': 161.5,
#   'reposts_median': 8.5},
#  '#Skillbox_дизайн': {'post_count': 18,
#   'likes_min': 27,
#   'reposts_min': 0,
#   'likes_max': 377,
#   'reposts_max': 29,
#   'likes_mean': 112.5,
#   'reposts_mean': 6.611111111111111,
#   'likes_median': 77.5,
#   'reposts_median': 5.0},
#  '#Skillbox_маркетинг': {'post_count': 8,
#   'likes_min': 33,
#   'reposts_min': 1,
#   'likes_max': 250,
#   'reposts_max': 54,
#   'likes_mean': 87.875,
#   'reposts_mean': 12.125,
#   'likes_median': 59.0,
#   'reposts_median': 6.0},
#  '#Skillbox_программирование': {'post_count': 9,
#   'likes_min': 40,
#   'reposts_min': 0,
#   'likes_max': 252,
#   'reposts_max': 33,
#   'likes_mean': 94.11111111111111,
#   'reposts_mean': 10.666666666666666,
#   'likes_median': 79.0,
#   'reposts_median': 8.0},
#  '#Skillbox_управление': {'post_count': 3,
#   'likes_min': 26,
#   'reposts_min': 1,
#   'likes_max': 98,
#   'reposts_max': 13,
#   'likes_mean': 53.666666666666664,
#   'reposts_mean': 5.0,
#   'likes_median': 37.0,
#   'reposts_median': 1.0},
#  '#Skillboxвдохновляет': {'post_count': 1,
#   'likes_min': 157,
#   'reposts_min': 7,
#   'likes_max': 157,
#   'reposts_max': 7,
#   'likes_mean': 157.0,
#   'reposts_mean': 7.0,
#   'likes_median': 157.0,
#   'reposts_median': 7.0},
#  '#Skillboxпрограммирование': {'post_count': 1,
#   'likes_min': 177,
#   'reposts_min': 31,
#   'likes_max': 177,
#   'reposts_max': 31,
#   'likes_mean': 177.0,
#   'reposts_mean': 31.0,
#   'likes_median': 177.0,
#   'reposts_median': 31.0},
#  '#skillbox_дизайн': {'post_count': 1,
#   'likes_min': 319,
#   'reposts_min': 26,
#   'likes_max': 319,
#   'reposts_max': 26,
#   'likes_mean': 319.0,
#   'reposts_mean': 26.0,
#   'likes_median': 319.0,
#   'reposts_median': 26.0},
#  '#Айдентика_Skillbox': {'post_count': 1,
#   'likes_min': 99,
#   'reposts_min': 4,
#   'likes_max': 99,
#   'reposts_max': 4,
#   'likes_mean': 99.0,
#   'reposts_mean': 4.0,
#   'likes_median': 99.0,
#   'reposts_median': 4.0},
#  '#Альпина_Skillbox': {'post_count': 1,
#   'likes_min': 32,
#   'reposts_min': 5,
#   'likes_max': 32,
#   'reposts_max': 5,
#   'likes_mean': 32.0,
#   'reposts_mean': 5.0,
#   'likes_median': 32.0,
#   'reposts_median': 5.0},
#  '#Анонс_Skillbox': {'post_count': 5,
#   'likes_min': 26,
#   'reposts_min': 1,
#   'likes_max': 53,
#   'reposts_max': 5,
#   'likes_mean': 36.8,
#   'reposts_mean': 2.6,
#   'likes_median': 36.0,
#   'reposts_median': 1.0},
#  '#Анонс_курса': {'post_count': 1,
#   'likes_min': 64,
#   'reposts_min': 0,
#   'likes_max': 64,
#   'reposts_max': 0,
#   'likes_mean': 64.0,
#   'reposts_mean': 0.0,
#   'likes_median': 64.0,
#   'reposts_median': 0.0},
#  '#БудуВSkillbox': {'post_count': 1,
#   'likes_min': 53,
#   'reposts_min': 5,
#   'likes_max': 53,
#   'reposts_max': 5,
#   'likes_mean': 53.0,
#   'reposts_mean': 5.0,
#   'likes_median': 53.0,
#   'reposts_median': 5.0},
#  '#В_Закладки_Skillbox': {'post_count': 7,
#   'likes_min': 52,
#   'reposts_min': 7,
#   'likes_max': 298,
#   'reposts_max': 33,
#   'likes_mean': 164.71428571428572,
#   'reposts_mean': 20.714285714285715,
#   'likes_median': 162.0,
#   'reposts_median': 23.0},
#  '#В_Закладки_skillbox': {'post_count': 1,
#   'likes_min': 66,
#   'reposts_min': 0,
#   'likes_max': 66,
#   'reposts_max': 0,
#   'likes_mean': 66.0,
#   'reposts_mean': 0.0,
#   'likes_median': 66.0,
#   'reposts_median': 0.0},
#  '#В_закладки_Skillbox': {'post_count': 13,
#   'likes_min': 47,
#   'reposts_min': 1,
#   'likes_max': 250,
#   'reposts_max': 54,
#   'likes_mean': 113.46153846153847,
#   'reposts_mean': 14.076923076923077,
#   'likes_median': 98.0,
#   'reposts_median': 10.0},
#  '#Вам_слово_Skillbox': {'post_count': 1,
#   'likes_min': 26,
#   'reposts_min': 1,
#   'likes_max': 26,
#   'reposts_max': 1,
#   'likes_mean': 26.0,
#   'reposts_mean': 1.0,
#   'likes_median': 26.0,
#   'reposts_median': 1.0},
#  '#ДеньНаблюденияЗаОблаками': {'post_count': 1,
#   'likes_min': 51,
#   'reposts_min': 2,
#   'likes_max': 51,
#   'reposts_max': 2,
#   'likes_mean': 51.0,
#   'reposts_mean': 2.0,
#   'likes_median': 51.0,
#   'reposts_median': 2.0},
#  '#ДеньПрогульщика': {'post_count': 1,
#   'likes_min': 26,
#   'reposts_min': 1,
#   'likes_max': 26,
#   'reposts_max': 1,
#   'likes_mean': 26.0,
#   'reposts_mean': 1.0,
#   'likes_median': 26.0,
#   'reposts_median': 1.0},
#  '#ДеньШвеции': {'post_count': 1,
#   'likes_min': 125,
#   'reposts_min': 8,
#   'likes_max': 125,
#   'reposts_max': 8,
#   'likes_mean': 125.0,
#   'reposts_mean': 8.0,
#   'likes_median': 125.0,
#   'reposts_median': 8.0},
#  '#Игра_Skillbox': {'post_count': 2,
#   'likes_min': 31,
#   'reposts_min': 0,
#   'likes_max': 40,
#   'reposts_max': 3,
#   'likes_mean': 35.5,
#   'reposts_mean': 1.5,
#   'likes_median': 35.5,
#   'reposts_median': 1.5},
#  '#Иллюстрации': {'post_count': 1,
#   'likes_min': 192,
#   'reposts_min': 7,
#   'likes_max': 192,
#   'reposts_max': 7,
#   'likes_mean': 192.0,
#   'reposts_mean': 7.0,
#   'likes_median': 192.0,
#   'reposts_median': 7.0},
#  '#Иллюстрация_Skillbox': {'post_count': 1,
#   'likes_min': 224,
#   'reposts_min': 13,
#   'likes_max': 224,
#   'reposts_max': 13,
#   'likes_mean': 224.0,
#   'reposts_mean': 13.0,
#   'likes_median': 224.0,
#   'reposts_median': 13.0},
#  '#Качаем_креатив': {'post_count': 1,
#   'likes_min': 43,
#   'reposts_min': 5,
#   'likes_max': 43,
#   'reposts_max': 5,
#   'likes_mean': 43.0,
#   'reposts_mean': 5.0,
#   'likes_median': 43.0,
#   'reposts_median': 5.0},
#  '#Кейс_Skillbox': {'post_count': 1,
#   'likes_min': 33,
#   'reposts_min': 1,
#   'likes_max': 33,
#   'reposts_max': 1,
#   'likes_mean': 33.0,
#   'reposts_mean': 1.0,
#   'likes_median': 33.0,
#   'reposts_median': 1.0},
#  '#Конкурс_Skillbox': {'post_count': 1,
#   'likes_min': 63,
#   'reposts_min': 5,
#   'likes_max': 63,
#   'reposts_max': 5,
#   'likes_mean': 63.0,
#   'reposts_mean': 5.0,
#   'likes_median': 63.0,
#   'reposts_median': 5.0},
#  '#Лекторий_Skillbox': {'post_count': 4,
#   'likes_min': 29,
#   'reposts_min': 2,
#   'likes_max': 42,
#   'reposts_max': 4,
#   'likes_mean': 33.25,
#   'reposts_mean': 3.0,
#   'likes_median': 31.0,
#   'reposts_median': 3.0},
#  '#МоушнSkillbox': {'post_count': 1,
#   'likes_min': 157,
#   'reposts_min': 7,
#   'likes_max': 157,
#   'reposts_max': 7,
#   'likes_mean': 157.0,
#   'reposts_mean': 7.0,
#   'likes_median': 157.0,
#   'reposts_median': 7.0},
#  '#Новости_Skillbox': {'post_count': 1,
#   'likes_min': 93,
#   'reposts_min': 3,
#   'likes_max': 93,
#   'reposts_max': 3,
#   'likes_mean': 93.0,
#   'reposts_mean': 3.0,
#   'likes_median': 93.0,
#   'reposts_median': 3.0},
#  '#Расписание_Skillbox': {'post_count': 8,
#   'likes_min': 29,
#   'reposts_min': 1,
#   'likes_max': 55,
#   'reposts_max': 8,
#   'likes_mean': 41.5,
#   'reposts_mean': 3.0,
#   'likes_median': 40.5,
#   'reposts_median': 2.5},
#  '#Советпрепода_Skillbox': {'post_count': 1,
#   'likes_min': 177,
#   'reposts_min': 31,
#   'likes_max': 177,
#   'reposts_max': 31,
#   'likes_mean': 177.0,
#   'reposts_mean': 31.0,
#   'likes_median': 177.0,
#   'reposts_median': 31.0},
#  '#Статья_Skillbox': {'post_count': 27,
#   'likes_min': 15,
#   'reposts_min': 0,
#   'likes_max': 118,
#   'reposts_max': 26,
#   'likes_mean': 60.25925925925926,
#   'reposts_mean': 8.444444444444445,
#   'likes_median': 59.0,
#   'reposts_median': 6.0},
#  '#Студенты_Skillbox': {'post_count': 2,
#   'likes_min': 82,
#   'reposts_min': 1,
#   'likes_max': 126,
#   'reposts_max': 6,
#   'likes_mean': 104.0,
#   'reposts_mean': 3.5,
#   'likes_median': 104.0,
#   'reposts_median': 3.5},
#  '#Тренировка_Skillbox': {'post_count': 1,
#   'likes_min': 27,
#   'reposts_min': 2,
#   'likes_max': 27,
#   'reposts_max': 2,
#   'likes_mean': 27.0,
#   'reposts_mean': 2.0,
#   'likes_median': 27.0,
#   'reposts_median': 2.0},
#  '#Упаковка_Skillbox': {'post_count': 2,
#   'likes_min': 73,
#   'reposts_min': 5,
#   'likes_max': 377,
#   'reposts_max': 13,
#   'likes_mean': 225.0,
#   'reposts_mean': 9.0,
#   'likes_median': 225.0,
#   'reposts_median': 9.0},
#  '#Учим_HTML': {'post_count': 2,
#   'likes_min': 104,
#   'reposts_min': 11,
#   'likes_max': 252,
#   'reposts_max': 33,
#   'likes_mean': 178.0,
#   'reposts_mean': 22.0,
#   'likes_median': 178.0,
#   'reposts_median': 22.0},
#  '#Шрифты_Skillbox': {'post_count': 1,
#   'likes_min': 113,
#   'reposts_min': 11,
#   'likes_max': 113,
#   'reposts_max': 11,
#   'likes_mean': 113.0,
#   'reposts_mean': 11.0,
#   'likes_median': 113.0,
#   'reposts_median': 11.0},
#  '#анонс_skillbox': {'post_count': 1,
#   'likes_min': 58,
#   'reposts_min': 8,
#   'likes_max': 58,
#   'reposts_max': 8,
#   'likes_mean': 58.0,
#   'reposts_mean': 8.0,
#   'likes_median': 58.0,
#   'reposts_median': 8.0},
#  '#в_закладки_skillbox': {'post_count': 1,
#   'likes_min': 319,
#   'reposts_min': 26,
#   'likes_max': 319,
#   'reposts_max': 26,
#   'likes_mean': 319.0,
#   'reposts_mean': 26.0,
#   'likes_median': 319.0,
#   'reposts_median': 26.0}}

# %%
pd.DataFrame(hashtag_dict).T.sort_values(['likes_median', 'reposts_median'],  ascending=[False, False])
# Out:
#                             post_count  likes_min  reposts_min  likes_max  \
# #skillbox_дизайн                   1.0      319.0         26.0      319.0
# #в_закладки_skillbox               1.0      319.0         26.0      319.0
# #Упаковка_Skillbox                 2.0       73.0          5.0      377.0
# #Иллюстрация_Skillbox              1.0      224.0         13.0      224.0
# #Иллюстрации                       1.0      192.0          7.0      192.0
# #Учим_HTML                         2.0      104.0         11.0      252.0
# #Skillboxпрограммирование          1.0      177.0         31.0      177.0
# #Советпрепода_Skillbox             1.0      177.0         31.0      177.0
# #В_Закладки_Skillbox               7.0       52.0          7.0      298.0
# #Skillbox_вдохновляет              2.0       99.0          4.0      224.0
# #Skillboxвдохновляет               1.0      157.0          7.0      157.0
# #МоушнSkillbox                     1.0      157.0          7.0      157.0
# #ДеньШвеции                        1.0      125.0          8.0      125.0
# #Шрифты_Skillbox                   1.0      113.0         11.0      113.0
# #Студенты_Skillbox                 2.0       82.0          1.0      126.0
# #Skillbox_Управление               1.0      102.0         26.0      102.0
# #Айдентика_Skillbox                1.0       99.0          4.0       99.0
# #В_закладки_Skillbox              13.0       47.0          1.0      250.0
# #Новости_Skillbox                  1.0       93.0          3.0       93.0
# #Skillbox_Дизайн                   8.0        6.0          1.0      144.0
# #Skillbox_программирование         9.0       40.0          0.0      252.0
# #Skillbox_дизайн                  18.0       27.0          0.0      377.0
# #SMDay                             1.0       68.0          1.0       68.0
# #В_Закладки_skillbox               1.0       66.0          0.0       66.0
# #Анонс_курса                       1.0       64.0          0.0       64.0
# #Skillbox_Маркетинг                2.0       44.0          4.0       82.0
# #Конкурс_Skillbox                  1.0       63.0          5.0       63.0
# #Skillbox_маркетинг                8.0       33.0          1.0      250.0
# #Статья_Skillbox                  27.0       15.0          0.0      118.0
# #анонс_skillbox                    1.0       58.0          8.0       58.0
# #Game_of_jobs                      1.0       53.0          5.0       53.0
# #БудуВSkillbox                     1.0       53.0          5.0       53.0
# #ДеньНаблюденияЗаОблаками          1.0       51.0          2.0       51.0
# #Skillbox_Программирование         5.0       38.0          0.0       56.0
# #Качаем_креатив                    1.0       43.0          5.0       43.0
# #Расписание_Skillbox               8.0       29.0          1.0       55.0
# #Skillbox_управление               3.0       26.0          1.0       98.0
# #Анонс_Skillbox                    5.0       26.0          1.0       53.0
# #Игра_Skillbox                     2.0       31.0          0.0       40.0
# #Кейс_Skillbox                     1.0       33.0          1.0       33.0
# #Альпина_Skillbox                  1.0       32.0          5.0       32.0
# #Лекторий_Skillbox                 4.0       29.0          2.0       42.0
# #Тренировка_Skillbox               1.0       27.0          2.0       27.0
# #Вам_слово_Skillbox                1.0       26.0          1.0       26.0
# #ДеньПрогульщика                   1.0       26.0          1.0       26.0
#
#                             reposts_max  likes_mean  reposts_mean  \
# #skillbox_дизайн                   26.0  319.000000     26.000000
# #в_закладки_skillbox               26.0  319.000000     26.000000
# #Упаковка_Skillbox                 13.0  225.000000      9.000000
# #Иллюстрация_Skillbox              13.0  224.000000     13.000000
# #Иллюстрации                        7.0  192.000000      7.000000
# #Учим_HTML                         33.0  178.000000     22.000000
# #Skillboxпрограммирование          31.0  177.000000     31.000000
# #Советпрепода_Skillbox             31.0  177.000000     31.000000
# #В_Закладки_Skillbox               33.0  164.714286     20.714286
# #Skillbox_вдохновляет              13.0  161.500000      8.500000
# #Skillboxвдохновляет                7.0  157.000000      7.000000
# #МоушнSkillbox                      7.0  157.000000      7.000000
# #ДеньШвеции                         8.0  125.000000      8.000000
# #Шрифты_Skillbox                   11.0  113.000000     11.000000
# #Студенты_Skillbox                  6.0  104.000000      3.500000
# #Skillbox_Управление               26.0  102.000000     26.000000
# #Айдентика_Skillbox                 4.0   99.000000      4.000000
# #В_закладки_Skillbox               54.0  113.461538     14.076923
# #Новости_Skillbox                   3.0   93.000000      3.000000
# #Skillbox_Дизайн                   19.0   78.375000      8.875000
# #Skillbox_программирование         33.0   94.111111     10.666667
# #Skillbox_дизайн                   29.0  112.500000      6.611111
# #SMDay                              1.0   68.000000      1.000000
# #В_Закладки_skillbox                0.0   66.000000      0.000000
# #Анонс_курса                        0.0   64.000000      0.000000
# #Skillbox_Маркетинг                20.0   63.000000     12.000000
# #Конкурс_Skillbox                   5.0   63.000000      5.000000
# #Skillbox_маркетинг                54.0   87.875000     12.125000
# #Статья_Skillbox                   26.0   60.259259      8.444444
# #анонс_skillbox                     8.0   58.000000      8.000000
# #Game_of_jobs                       5.0   53.000000      5.000000
# #БудуВSkillbox                      5.0   53.000000      5.000000
# #ДеньНаблюденияЗаОблаками           2.0   51.000000      2.000000
# #Skillbox_Программирование         10.0   47.000000      4.600000
# #Качаем_креатив                     5.0   43.000000      5.000000
# #Расписание_Skillbox                8.0   41.500000      3.000000
# #Skillbox_управление               13.0   53.666667      5.000000
# #Анонс_Skillbox                     5.0   36.800000      2.600000
# #Игра_Skillbox                      3.0   35.500000      1.500000
# #Кейс_Skillbox                      1.0   33.000000      1.000000
# #Альпина_Skillbox                   5.0   32.000000      5.000000
# #Лекторий_Skillbox                  4.0   33.250000      3.000000
# #Тренировка_Skillbox                2.0   27.000000      2.000000
# #Вам_слово_Skillbox                 1.0   26.000000      1.000000
# #ДеньПрогульщика                    1.0   26.000000      1.000000
#
#                             likes_median  reposts_median
# #skillbox_дизайн                   319.0            26.0
# #в_закладки_skillbox               319.0            26.0
# #Упаковка_Skillbox                 225.0             9.0
# #Иллюстрация_Skillbox              224.0            13.0
# #Иллюстрации                       192.0             7.0
# #Учим_HTML                         178.0            22.0
# #Skillboxпрограммирование          177.0            31.0
# #Советпрепода_Skillbox             177.0            31.0
# #В_Закладки_Skillbox               162.0            23.0
# #Skillbox_вдохновляет              161.5             8.5
# #Skillboxвдохновляет               157.0             7.0
# #МоушнSkillbox                     157.0             7.0
# #ДеньШвеции                        125.0             8.0
# #Шрифты_Skillbox                   113.0            11.0
# #Студенты_Skillbox                 104.0             3.5
# #Skillbox_Управление               102.0            26.0
# #Айдентика_Skillbox                 99.0             4.0
# #В_закладки_Skillbox                98.0            10.0
# #Новости_Skillbox                   93.0             3.0
# #Skillbox_Дизайн                    87.0             8.5
# #Skillbox_программирование          79.0             8.0
# #Skillbox_дизайн                    77.5             5.0
# #SMDay                              68.0             1.0
# #В_Закладки_skillbox                66.0             0.0
# #Анонс_курса                        64.0             0.0
# #Skillbox_Маркетинг                 63.0            12.0
# #Конкурс_Skillbox                   63.0             5.0
# #Skillbox_маркетинг                 59.0             6.0
# #Статья_Skillbox                    59.0             6.0
# #анонс_skillbox                     58.0             8.0
# #Game_of_jobs                       53.0             5.0
# #БудуВSkillbox                      53.0             5.0
# #ДеньНаблюденияЗаОблаками           51.0             2.0
# #Skillbox_Программирование          45.0             3.0
# #Качаем_креатив                     43.0             5.0
# #Расписание_Skillbox                40.5             2.5
# #Skillbox_управление                37.0             1.0
# #Анонс_Skillbox                     36.0             1.0
# #Игра_Skillbox                      35.5             1.5
# #Кейс_Skillbox                      33.0             1.0
# #Альпина_Skillbox                   32.0             5.0
# #Лекторий_Skillbox                  31.0             3.0
# #Тренировка_Skillbox                27.0             2.0
# #Вам_слово_Skillbox                 26.0             1.0
# #ДеньПрогульщика                    26.0             1.0

# %% [markdown]
# ## Вывод:##
#
# Из полученного выше датафрейме видно, что больше всего лайков получила статья с хештегом "#skillbox_дизайн", это еще раз доказывает, что курсы по дизайну на сегодняйший день очень популярены. Меня очень огорчает, что программирование не занимает первую строчку по популярности.
