# %% [markdown]
# ## Модуль 8. Частные производные функции нескольких переменных.
#
# # Домашнее задание.
#
#
#
#  ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA.JPG](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA.JPG)

# %%
from sympy import *
from sympy.plotting import plot
from sympy.plotting import plot3d
import matplotlib.pyplot as plt

init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %% [markdown]
# ## Задание №1
# # а) $f(x,y)=x(y-5)^2$

# %%
x, y = symbols('x, y')

# %%
f1 = x*(y-5)**2
f1
# Out:
#          2
# x*(y - 5)

# %%
#Производная по x
f2 = diff(f1, x)
f2
# Out:
#        2
# (y - 5)

# %%
plot3d(f2)

# %%
#Нули производной по x:
f3 = solve(f2)
f3
# Out:
# [5]

# %%
plot(diff(f1, x))

# %%
#Производная по y
f4 = diff(f1, y)
f4
# Out:
# x*(2*y - 10)

# %%
plot3d(f4)

# %%
#Нули производной по y:
f5 = solve(f4)
f5
# Out:
# [{x: 0}, {y: 5}]

# %% [markdown]
# # б) $f(x,y)=(y-e/20)^2 sin(pi^x)$

# %%
f6 = (y - E/20)**2 * sin(pi*x)
f6
# Out:
#         2
# /    E \
# |y - --| *sin(pi*x)
# \    20/

# %%
#Производная по x
f7 = diff(f6, x)
f7
# Out:
#            2
#    /    E \
# pi*|y - --| *cos(pi*x)
#    \    20/

# %%
plot3d(f7)

# %%
#Нули производной по x:
f8 = solve(f7)
f8
# Out:
#                          E
# [{x: 1/2}, {x: 3/2}, {y: --}]
#                          20

# %%
#Производная по y
f9 = diff(f6, y)
f9
# Out:
# /      E \
# |2*y - --|*sin(pi*x)
# \      10/

# %%
plot3d(f9)

# %%
#Нули производной по y:
f10 = solve(f9)
f10
# Out:
#                      E
# [{x: 0}, {x: 1}, {y: --}]
#                      20

# %% [markdown]
# # в) $f(x,y)=x sin(x) sin(y-2)$

# %%
f11 =x*sin(x)*sin(y-2)
f11
# Out:
# x*sin(x)*sin(y - 2)

# %%
#Производная по x
f12 = diff(f11, x)
f12
# Out:
# x*sin(y - 2)*cos(x) + sin(x)*sin(y - 2)

# %%
plot3d(f12)

# %%
#Нули производной по x:
f13 = solve(f12)
f13
# Out:
# [{y: 2}, {y: 2 + pi}]

# %%
#Производная по y
f14 = diff(f1, y)
f14
# Out:
# x*(2*y - 10)

# %%
plot3d(f14)

# %%
#Нули производной по y:
f15 = solve(f14)
f15
# Out:
# [{x: 0}, {y: 5}]

# %% [markdown]
# ## Задание №2

# %%
from sympy import *

# %%
a0, a1, a2 = symbols('a0, a1, a2')

# %%
MSE = 1/3 * (((a2 * 560 + a1 * 1945 + a0) - 4.3)**2 + \
             ((a2 * 340 + a1 * 1495 + a0) - 4.9)**2 + \
             ((a2 * 343 + a1 * 1570 + a0) - 5.2)**2)
MSE
# Out:
#                                                2                                                  2                                                  2
# 0.333333333333333*(a0 + 1495*a1 + 340*a2 - 4.9)  + 0.333333333333333*(a0 + 1570*a1 + 343*a2 - 5.2)  + 0.333333333333333*(a0 + 1945*a1 + 560*a2 - 4.3)

# %%
MSEa2 = diff(MSE, a2)
MSEa2
# Out:
# 828.666666666667*a0 + 1424006.66666667*a1 + 364566.0*a2 - 3905.06666666667

# %%
MSEa1 = diff(MSE, a1)
MSEa1
# Out:
# 3340.0*a0 + 5655300.0*a1 + 1424006.66666667*a2 - 15902.0

# %%
MSEa0 = diff(MSE, a0)
MSEa0
# Out:
# 2.0*a0 + 3340.0*a1 + 828.666666666667*a2 - 9.6

# %%
nonlinsolve([MSEa2, MSEa1, MSEa0], [a2, a1, a0])
# Out:
# {(-0.0118811881188048, 0.00447524752474873, 2.2491089108944)}

# %%
MSE.subs({'a2': -0.0118811881188096, 'a1': 0.00447524752475122, 'a0': 2.24910891089222})
# Out:
# 1.77704066582787e-27

# %%
MSE.subs({'a2': -0.0118811881188096, 'a1': -0.00447524752475122, 'a0': 2.24910891089222})
# Out:
# 226.526891716372

# %%
x2, x1 = symbols('x2, x1')

# %%
f1 = -0.0118811881188096 * x2 + 0.00447524752475122 * x1 + 2.24910891089222
f1
# Out:
# 0.00447524752475122*x1 - 0.0118811881188096*x2 + 2.24910891089222

# %%
f1.subs({'x2': 431, 'x1': 1520})
# Out:
# 3.93069306930714
