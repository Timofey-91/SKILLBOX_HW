# %% [markdown]
# # Реализация модернизированной FCN сети

# %% [markdown]
# ### Загрузка необходимых библиотек
# В TensorFlow включаем режим жадного (eager) выполнения и проверяем версию (должна быть 1.14)

# %%
import random
import imageio
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

import tensorflow as tf
tf.enable_eager_execution()
print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 1.14.0

# %% [markdown]
# # Подготовка датасета

# %% [markdown]
# ### Загрузка и подготовка входного изображения

# %%
img = imageio.imread('me_256.png')
img = img.astype(np.float32) / 255.
_=plt.imshow(img)

# %% [markdown]
# ### Загрузка и подготовка карты сегментации человек/фон

# %%
gt = imageio.imread('me_gt_256.png')
gt = gt.astype(np.float32) / 255.
gt = np.mean(gt, axis=2)[...,None]
_=plt.imshow(gt[...,0])

# %% [markdown]
# ### Подготовка обучающего датасета
# Наша цель создать пайплайн для обучения, включая данные, модель, лосс и т.д.
#
# Поэтому для простоты возьмем очень простой датасет, состоящий из двух изображений: загруженная картинка и её зеркально отраженная копия.
#
# При обучении на таком маленьком датасете модель переобучится, но в данном примере нас это не будет беспокоить. Наша цель - отладить пайплайн, поэтому тестировать будем на том же, на чём и обучались

# %%
train_x = np.stack((img, img[:,::-1,:]))
train_y = np.stack((gt, gt[:,::-1,:]))

plt.imshow(train_x[0]), plt.show()
plt.imshow(train_y[0][...,0]), plt.show()
plt.imshow(train_x[1]), plt.show()
plt.imshow(train_y[1][...,0]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x19e1a693d30>, None)

# %% [markdown]
# # Пайплайн обучения FCN

# %% [markdown]
# ### Создание FCN модели
# Для понижения размерности используются свёртки со страйдом. Для повышения размерности - Unpooling (nearest neighbour)
#
# Модель создаётся путём наслелования от `tf.keras.Model`.
#
# В методе `Model.__init__` создаются слои.
#
# В методе `Model.call` производится инференс с использованием созданных слоёв и других функций TensorFlow

# %%
class Model(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        
        self.conv3 = tf.keras.layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same', activation='relu')
        
        self.conv4 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv5 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        
        self.conv6 = tf.keras.layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same', activation='relu')
        
        self.conv7 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv8 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        
        self.conv9 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv10 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        
        self.conv11 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv12 = tf.keras.layers.Conv2D(1, (3, 3), padding='same', activation='sigmoid')
        
        self.unpool = tf.keras.layers.UpSampling2D((2, 2))
                
    def call(self, x):
        out = self.conv1(x)
        out = self.conv2(out)
        out = self.conv3(out)
        
        out = self.conv4(out)
        out = self.conv5(out)
        out = self.conv6(out)
        
        out = self.conv7(out)
        out = self.conv8(out)
        out = self.unpool(out)
        
        out = self.conv9(out)
        out = self.conv10(out)
        out = self.unpool(out)
        
        out = self.conv11(out)
        out = self.conv12(out)

        return out
    
model = Model()

# %% [markdown]
# ### Параметры обучения

# %%
NUM_EPOCHS = 100

# %% [markdown]
# ### Подготовка модели к обучению
# В качестве лосса используется бинарная кросс-энтропия (BinaryCrossentropy).
# В лоссе автоматически происходит суммирование по всем измерениям.

# %%
loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer='adam', loss=loss)

# %% [markdown]
# ### Обучение модели

# %%
history = model.fit(train_x, train_y, batch_size=1, epochs=NUM_EPOCHS)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0812 16:40:25.621922  9832 deprecation.py:323] From C:\Users\LK\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 2/2 [==============================] - 3s 1s/sample - loss: 0.6842
# Epoch 2/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.8651
# Epoch 3/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.6734
# Epoch 4/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.6593
# Epoch 5/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.6071
# Epoch 6/100
# 2/2 [==============================] - 0s 72ms/sample - loss: 0.4400
# Epoch 7/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.2870
# Epoch 8/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.3258
# Epoch 9/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.3323
# Epoch 10/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.2837
# Epoch 11/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.2516
# Epoch 12/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.2520
# Epoch 13/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.2251
# Epoch 14/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.2199
# Epoch 15/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.2176
# Epoch 16/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1970
# Epoch 17/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.1695
# Epoch 18/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.1238
# Epoch 19/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.3015
# Epoch 20/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.2412
# Epoch 21/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1586
# Epoch 22/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.1625
# Epoch 23/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1577
# Epoch 24/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1330
# Epoch 25/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1083
# Epoch 26/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0783
# Epoch 27/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0823
# Epoch 28/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.5079
# Epoch 29/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.3093
# Epoch 30/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1587
# Epoch 31/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.2177
# Epoch 32/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.2253
# Epoch 33/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.2043
# Epoch 34/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.1955
# Epoch 35/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.1891
# Epoch 36/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.1771
# Epoch 37/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1530
# Epoch 38/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1041
# Epoch 39/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1366
# Epoch 40/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1286
# Epoch 41/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.2801
# Epoch 42/100
# 2/2 [==============================] - 0s 72ms/sample - loss: 0.1352
# Epoch 43/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.1465
# Epoch 44/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1698
# Epoch 45/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1601
# Epoch 46/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1544
# Epoch 47/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.1284
# Epoch 48/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.1038
# Epoch 49/100
# 2/2 [==============================] - 0s 72ms/sample - loss: 0.0723
# Epoch 50/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0504
# Epoch 51/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0454
# Epoch 52/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0428
# Epoch 53/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0389
# Epoch 54/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0387
# Epoch 55/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0310
# Epoch 56/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0289
# Epoch 57/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0276
# Epoch 58/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0260
# Epoch 59/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0240
# Epoch 60/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.0227
# Epoch 61/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.0212
# Epoch 62/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0208
# Epoch 63/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0193
# Epoch 64/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0187
# Epoch 65/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0178
# Epoch 66/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0170
# Epoch 67/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0161
# Epoch 68/100
# 2/2 [==============================] - 0s 72ms/sample - loss: 0.0154
# Epoch 69/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0146
# Epoch 70/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0139
# Epoch 71/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0133
# Epoch 72/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0126
# Epoch 73/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.0130
# Epoch 74/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0125
# Epoch 75/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0122
# Epoch 76/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0116
# Epoch 77/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0116
# Epoch 78/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0182
# Epoch 79/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0142
# Epoch 80/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0112
# Epoch 81/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0114
# Epoch 82/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.0118
# Epoch 83/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0117
# Epoch 84/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.0114
# Epoch 85/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0108
# Epoch 86/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0100
# Epoch 87/100
# 2/2 [==============================] - 0s 72ms/sample - loss: 0.0093
# Epoch 88/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.0094
# Epoch 89/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0093
# Epoch 90/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0085
# Epoch 91/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0083
# Epoch 92/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0075
# Epoch 93/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.0080
# Epoch 94/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0077
# Epoch 95/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.0072
# Epoch 96/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0069
# Epoch 97/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0065
# Epoch 98/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0067
# Epoch 99/100
# 2/2 [==============================] - 0s 73ms/sample - loss: 0.0065
# Epoch 100/100
# 2/2 [==============================] - 0s 74ms/sample - loss: 0.0063

# %% [markdown]
# ### График зависимости лосса от эпохи

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# ### Результат предсказания на входной картинке

# %%
out = model.predict(img[None, ...])
_=plt.imshow(out[0, ..., 0])

# %% [markdown]
# ### Результат предсказания для всех картинок
# По предсказанию сети получается карта сегментации с помощью порога.
#
# Далее она отображается поверх исходной картинки.

# %%
for sample in train_x:
    out = model.predict(sample[None, ...])
    seg_map = (out[0, ..., 0]>0.5).astype(np.float32)
    seg_map_clr = plt.get_cmap('jet')(seg_map)[..., :3]
    plt.imshow(sample*0.5 + seg_map_clr*0.5)
    plt.show()
