# %% [markdown]
# # Сохранение и возобновление обучения в Tensorflow
#
# До этого момента мы с вами работали с "игрушечными" данными и основной целью было понять основные механизмы работы фреймворка, обучения и построения моделей.
#
# Раньше мы не думали о том, как можно использовать обученную модель в будущем и сохранять параметры, которые мы получили во время обучения.
#
# Именно об этих возможностях, обязательных в практическом применении сетей, и пойдет речь в этом уроке.

# %% [markdown]
# ## Датасет
#
# В этом уроке мы будем работать с датасетом Pima Indian Diabetes, в котором приведены данные о состоянии здоровья людей. Помимо физиологических показаний, в данных есть информация о наличии у человека диабета. Это и будет считаться классом.

# %%
# загрузим данные
! wget https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv
import pandas as pd

dataset = pd.read_csv("pima-indians-diabetes.data.csv", header=None)
dataset.columns = ["number_times_pregnant",
"plasma_glucose_concent","blood_pressure",
"skin_thickness", "insulin", "BMI", "diabetes_pedigree", "age", "has_diabetes"]
dataset.head()
# Out:
# --2021-06-19 13:12:00--  https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23278 (23K) [text/plain]
# Saving to: ‘pima-indians-diabetes.data.csv.1’
#
# pima-indians-diabet 100%[===================>]  22.73K  --.-KB/s    in 0.002s
#
# 2021-06-19 13:12:00 (12.3 MB/s) - ‘pima-indians-diabetes.data.csv.1’ saved [23278/23278]
#    number_times_pregnant  plasma_glucose_concent  ...  age  has_diabetes
# 0                      6                     148  ...   50             1
# 1                      1                      85  ...   31             0
# 2                      8                     183  ...   32             1
# 3                      1                      89  ...   21             0
# 4                      0                     137  ...   33             1
#
# [5 rows x 9 columns]

# %%
import numpy as np
from sklearn.model_selection import train_test_split

np.random.seed(10)
X = dataset.drop(['has_diabetes'], axis=1).values
y = dataset['has_diabetes'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}, Labels ratio: {y_train.mean():.2f}")
# Out:
# Train shape: (614, 8), Test shape: (154, 8), Labels ratio: 0.34

# %% [markdown]
# ## Сохранение и загрузка моделей
#
# Т.к. параметры нашей модели трансформируются путем оптимизации из случайных -- в полезные для нашей задачи, нам бы хотелось сохранять этот прогресс. Было бы неразумно каждый раз обучать модель заново. Сохранение параметров модели во время обучения называют -- чекпоинтом (checkpoint).
#
# Подходы к сохранению моделей могут варьироваться в зависимости от количества данных и сложности модели. Все они сводятся к правилам по которым решается когда сохранять модель. Приведем самые популярные из таких правил:
# *   Сохранение в конце каждой эпохи
# *   Сохранение каждые k эпох
# *   Сохранение только последней эпохи
# *   Сохранение весов при улучшении метрики

# %%
import tensorflow as tf
import numpy as np
#tf.enable_eager_execution()
print(tf.__version__)
# Out:
# 2.5.0

# %% [markdown]
# Для начала обучим модель и убедимся, что все работает:

# %%
def get_compiled_model():
    """
    Функция возвращает скомпилированную модель для бинарной классификации
    """
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(24, input_dim=8, activation='relu'))
    model.add(tf.keras.layers.Dense(24, activation='relu'))
    model.add(tf.keras.layers.Dense(24, activation='relu'))
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

model = get_compiled_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=64, verbose=1)
# Out:
# Epoch 1/150
# 10/10 [==============================] - 1s 23ms/step - loss: 3.0916 - accuracy: 0.5717 - val_loss: 0.8191 - val_accuracy: 0.6429
# Epoch 2/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6841 - accuracy: 0.6612 - val_loss: 0.6401 - val_accuracy: 0.6688
# Epoch 3/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6044 - accuracy: 0.6792 - val_loss: 0.6122 - val_accuracy: 0.7143
# Epoch 4/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6262 - accuracy: 0.6661 - val_loss: 0.6258 - val_accuracy: 0.6883
# Epoch 5/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6117 - accuracy: 0.6824 - val_loss: 0.6332 - val_accuracy: 0.6623
# Epoch 6/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6169 - accuracy: 0.6792 - val_loss: 0.6255 - val_accuracy: 0.6558
# Epoch 7/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5787 - accuracy: 0.7036 - val_loss: 0.6132 - val_accuracy: 0.6688
# Epoch 8/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5708 - accuracy: 0.7215 - val_loss: 0.6189 - val_accuracy: 0.6883
# Epoch 9/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5616 - accuracy: 0.7117 - val_loss: 0.6713 - val_accuracy: 0.6299
# Epoch 10/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5829 - accuracy: 0.7134 - val_loss: 0.6460 - val_accuracy: 0.6688
# Epoch 11/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5634 - accuracy: 0.7036 - val_loss: 0.6863 - val_accuracy: 0.6429
# Epoch 12/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5865 - accuracy: 0.7101 - val_loss: 0.7485 - val_accuracy: 0.6558
# Epoch 13/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6159 - accuracy: 0.6840 - val_loss: 0.6235 - val_accuracy: 0.6818
# Epoch 14/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5564 - accuracy: 0.7150 - val_loss: 0.6267 - val_accuracy: 0.6818
# Epoch 15/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5424 - accuracy: 0.7313 - val_loss: 0.6279 - val_accuracy: 0.7078
# Epoch 16/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5511 - accuracy: 0.7231 - val_loss: 0.6161 - val_accuracy: 0.7273
# Epoch 17/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5350 - accuracy: 0.7345 - val_loss: 0.6055 - val_accuracy: 0.6948
# Epoch 18/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5313 - accuracy: 0.7394 - val_loss: 0.6077 - val_accuracy: 0.6948
# Epoch 19/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5196 - accuracy: 0.7541 - val_loss: 0.6492 - val_accuracy: 0.7208
# Epoch 20/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5384 - accuracy: 0.7329 - val_loss: 0.6230 - val_accuracy: 0.6688
# Epoch 21/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5354 - accuracy: 0.7296 - val_loss: 0.5856 - val_accuracy: 0.7078
# Epoch 22/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5360 - accuracy: 0.7264 - val_loss: 0.6036 - val_accuracy: 0.6883
# Epoch 23/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5409 - accuracy: 0.7003 - val_loss: 0.5885 - val_accuracy: 0.7013
# Epoch 24/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5201 - accuracy: 0.7394 - val_loss: 0.6040 - val_accuracy: 0.6883
# Epoch 25/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5265 - accuracy: 0.7313 - val_loss: 0.5851 - val_accuracy: 0.7013
# Epoch 26/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5231 - accuracy: 0.7508 - val_loss: 0.5786 - val_accuracy: 0.7273
# Epoch 27/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5248 - accuracy: 0.7280 - val_loss: 0.5882 - val_accuracy: 0.6818
# Epoch 28/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5222 - accuracy: 0.7541 - val_loss: 0.5696 - val_accuracy: 0.7078
# Epoch 29/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5105 - accuracy: 0.7508 - val_loss: 0.5708 - val_accuracy: 0.6948
# Epoch 30/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5194 - accuracy: 0.7492 - val_loss: 0.5875 - val_accuracy: 0.7338
# Epoch 31/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5443 - accuracy: 0.7248 - val_loss: 0.5872 - val_accuracy: 0.7078
# Epoch 32/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5075 - accuracy: 0.7524 - val_loss: 0.5649 - val_accuracy: 0.7143
# Epoch 33/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5088 - accuracy: 0.7362 - val_loss: 0.5941 - val_accuracy: 0.7403
# Epoch 34/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5066 - accuracy: 0.7524 - val_loss: 0.6083 - val_accuracy: 0.7208
# Epoch 35/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5111 - accuracy: 0.7524 - val_loss: 0.6123 - val_accuracy: 0.6948
# Epoch 36/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4975 - accuracy: 0.7557 - val_loss: 0.5640 - val_accuracy: 0.7013
# Epoch 37/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4911 - accuracy: 0.7508 - val_loss: 0.5789 - val_accuracy: 0.7273
# Epoch 38/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4948 - accuracy: 0.7671 - val_loss: 0.5828 - val_accuracy: 0.7078
# Epoch 39/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5306 - accuracy: 0.7410 - val_loss: 0.5932 - val_accuracy: 0.7208
# Epoch 40/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5013 - accuracy: 0.7459 - val_loss: 0.5632 - val_accuracy: 0.7013
# Epoch 41/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4865 - accuracy: 0.7606 - val_loss: 0.5919 - val_accuracy: 0.7078
# Epoch 42/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4793 - accuracy: 0.7704 - val_loss: 0.6059 - val_accuracy: 0.7078
# Epoch 43/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4797 - accuracy: 0.7638 - val_loss: 0.5544 - val_accuracy: 0.6818
# Epoch 44/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4846 - accuracy: 0.7720 - val_loss: 0.5633 - val_accuracy: 0.7078
# Epoch 45/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4807 - accuracy: 0.7671 - val_loss: 0.5615 - val_accuracy: 0.6948
# Epoch 46/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4713 - accuracy: 0.7834 - val_loss: 0.6025 - val_accuracy: 0.7013
# Epoch 47/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4697 - accuracy: 0.7622 - val_loss: 0.6020 - val_accuracy: 0.6948
# Epoch 48/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4813 - accuracy: 0.7492 - val_loss: 0.6627 - val_accuracy: 0.6883
# Epoch 49/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4731 - accuracy: 0.7736 - val_loss: 0.6714 - val_accuracy: 0.6883
# Epoch 50/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5174 - accuracy: 0.7606 - val_loss: 0.7157 - val_accuracy: 0.6623
# Epoch 51/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5077 - accuracy: 0.7427 - val_loss: 0.5627 - val_accuracy: 0.6948
# Epoch 52/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4914 - accuracy: 0.7541 - val_loss: 0.5951 - val_accuracy: 0.7208
# Epoch 53/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4726 - accuracy: 0.7736 - val_loss: 0.5592 - val_accuracy: 0.7078
# Epoch 54/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4931 - accuracy: 0.7655 - val_loss: 0.5698 - val_accuracy: 0.7273
# Epoch 55/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4897 - accuracy: 0.7476 - val_loss: 0.5490 - val_accuracy: 0.7532
# Epoch 56/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4747 - accuracy: 0.7687 - val_loss: 0.6118 - val_accuracy: 0.7208
# Epoch 57/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4651 - accuracy: 0.7752 - val_loss: 0.5823 - val_accuracy: 0.7013
# Epoch 58/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4693 - accuracy: 0.7752 - val_loss: 0.5472 - val_accuracy: 0.7208
# Epoch 59/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4706 - accuracy: 0.7785 - val_loss: 0.5604 - val_accuracy: 0.7273
# Epoch 60/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4770 - accuracy: 0.7508 - val_loss: 0.5557 - val_accuracy: 0.6948
# Epoch 61/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4742 - accuracy: 0.7801 - val_loss: 0.5677 - val_accuracy: 0.7013
# Epoch 62/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4723 - accuracy: 0.7752 - val_loss: 0.5629 - val_accuracy: 0.7208
# Epoch 63/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5028 - accuracy: 0.7508 - val_loss: 0.5634 - val_accuracy: 0.7078
# Epoch 64/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4955 - accuracy: 0.7508 - val_loss: 0.5776 - val_accuracy: 0.7143
# Epoch 65/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4578 - accuracy: 0.7834 - val_loss: 0.6326 - val_accuracy: 0.6883
# Epoch 66/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4539 - accuracy: 0.7850 - val_loss: 0.6691 - val_accuracy: 0.7013
# Epoch 67/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4848 - accuracy: 0.7590 - val_loss: 0.6189 - val_accuracy: 0.7013
# Epoch 68/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4714 - accuracy: 0.7720 - val_loss: 0.5954 - val_accuracy: 0.7208
# Epoch 69/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4772 - accuracy: 0.7671 - val_loss: 0.6211 - val_accuracy: 0.6883
# Epoch 70/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5022 - accuracy: 0.7573 - val_loss: 0.5803 - val_accuracy: 0.6818
# Epoch 71/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4550 - accuracy: 0.7866 - val_loss: 0.5909 - val_accuracy: 0.7078
# Epoch 72/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4556 - accuracy: 0.7801 - val_loss: 0.5332 - val_accuracy: 0.7013
# Epoch 73/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4741 - accuracy: 0.7655 - val_loss: 0.5704 - val_accuracy: 0.7208
# Epoch 74/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4704 - accuracy: 0.7785 - val_loss: 0.5641 - val_accuracy: 0.7208
# Epoch 75/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4731 - accuracy: 0.7736 - val_loss: 0.5692 - val_accuracy: 0.7208
# Epoch 76/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4418 - accuracy: 0.7899 - val_loss: 0.5939 - val_accuracy: 0.7338
# Epoch 77/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4681 - accuracy: 0.7687 - val_loss: 0.6515 - val_accuracy: 0.6688
# Epoch 78/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4702 - accuracy: 0.7655 - val_loss: 0.6092 - val_accuracy: 0.7143
# Epoch 79/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4536 - accuracy: 0.7932 - val_loss: 0.6016 - val_accuracy: 0.7078
# Epoch 80/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4588 - accuracy: 0.7769 - val_loss: 0.6091 - val_accuracy: 0.7078
# Epoch 81/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4720 - accuracy: 0.7687 - val_loss: 0.5825 - val_accuracy: 0.7013
# Epoch 82/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4734 - accuracy: 0.7687 - val_loss: 0.5453 - val_accuracy: 0.7143
# Epoch 83/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4558 - accuracy: 0.7736 - val_loss: 0.5690 - val_accuracy: 0.7273
# Epoch 84/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4501 - accuracy: 0.7866 - val_loss: 0.5574 - val_accuracy: 0.7208
# Epoch 85/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4647 - accuracy: 0.7801 - val_loss: 0.5967 - val_accuracy: 0.7597
# Epoch 86/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4588 - accuracy: 0.7834 - val_loss: 0.5597 - val_accuracy: 0.7403
# Epoch 87/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4614 - accuracy: 0.7736 - val_loss: 0.5921 - val_accuracy: 0.7143
# Epoch 88/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4720 - accuracy: 0.7818 - val_loss: 0.5806 - val_accuracy: 0.7208
# Epoch 89/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4508 - accuracy: 0.7866 - val_loss: 0.5535 - val_accuracy: 0.7338
# Epoch 90/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4613 - accuracy: 0.7638 - val_loss: 0.6036 - val_accuracy: 0.6948
# Epoch 91/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4443 - accuracy: 0.7850 - val_loss: 0.5712 - val_accuracy: 0.7338
# Epoch 92/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4438 - accuracy: 0.7899 - val_loss: 0.5997 - val_accuracy: 0.7208
# Epoch 93/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4511 - accuracy: 0.7818 - val_loss: 0.5800 - val_accuracy: 0.7403
# Epoch 94/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4708 - accuracy: 0.7557 - val_loss: 0.5905 - val_accuracy: 0.6818
# Epoch 95/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4335 - accuracy: 0.7866 - val_loss: 0.6507 - val_accuracy: 0.7273
# Epoch 96/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4452 - accuracy: 0.7704 - val_loss: 0.6998 - val_accuracy: 0.7013
# Epoch 97/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4523 - accuracy: 0.7655 - val_loss: 0.6815 - val_accuracy: 0.6883
# Epoch 98/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4508 - accuracy: 0.7736 - val_loss: 0.6366 - val_accuracy: 0.7208
# Epoch 99/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4868 - accuracy: 0.7622 - val_loss: 0.5826 - val_accuracy: 0.7013
# Epoch 100/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5048 - accuracy: 0.7622 - val_loss: 0.6421 - val_accuracy: 0.7143
# Epoch 101/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4794 - accuracy: 0.7752 - val_loss: 0.5639 - val_accuracy: 0.7143
# Epoch 102/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4628 - accuracy: 0.7736 - val_loss: 0.6126 - val_accuracy: 0.7338
# Epoch 103/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4867 - accuracy: 0.7557 - val_loss: 0.6456 - val_accuracy: 0.6818
# Epoch 104/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4564 - accuracy: 0.7720 - val_loss: 0.6514 - val_accuracy: 0.6948
# Epoch 105/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4759 - accuracy: 0.7492 - val_loss: 0.5919 - val_accuracy: 0.7143
# Epoch 106/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4659 - accuracy: 0.7736 - val_loss: 0.5966 - val_accuracy: 0.7143
# Epoch 107/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4505 - accuracy: 0.7915 - val_loss: 0.5867 - val_accuracy: 0.6883
# Epoch 108/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4424 - accuracy: 0.7964 - val_loss: 0.7010 - val_accuracy: 0.6623
# Epoch 109/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4445 - accuracy: 0.7883 - val_loss: 0.5900 - val_accuracy: 0.7532
# Epoch 110/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4254 - accuracy: 0.7883 - val_loss: 0.5501 - val_accuracy: 0.7273
# Epoch 111/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4241 - accuracy: 0.8078 - val_loss: 0.6518 - val_accuracy: 0.6883
# Epoch 112/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4180 - accuracy: 0.7948 - val_loss: 0.6560 - val_accuracy: 0.6883
# Epoch 113/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4293 - accuracy: 0.8094 - val_loss: 0.6050 - val_accuracy: 0.7078
# Epoch 114/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4254 - accuracy: 0.7883 - val_loss: 0.6128 - val_accuracy: 0.7013
# Epoch 115/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4278 - accuracy: 0.7818 - val_loss: 0.6270 - val_accuracy: 0.7208
# Epoch 116/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4174 - accuracy: 0.7980 - val_loss: 0.6104 - val_accuracy: 0.7078
# Epoch 117/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4327 - accuracy: 0.7948 - val_loss: 0.7817 - val_accuracy: 0.6883
# Epoch 118/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4630 - accuracy: 0.7769 - val_loss: 0.6352 - val_accuracy: 0.7013
# Epoch 119/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4503 - accuracy: 0.7834 - val_loss: 0.5642 - val_accuracy: 0.7532
# Epoch 120/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4414 - accuracy: 0.7883 - val_loss: 0.5761 - val_accuracy: 0.7078
# Epoch 121/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4540 - accuracy: 0.7638 - val_loss: 0.5365 - val_accuracy: 0.7403
# Epoch 122/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4768 - accuracy: 0.7704 - val_loss: 0.6469 - val_accuracy: 0.7273
# Epoch 123/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4583 - accuracy: 0.7720 - val_loss: 0.5980 - val_accuracy: 0.7468
# Epoch 124/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4632 - accuracy: 0.7883 - val_loss: 0.5866 - val_accuracy: 0.7013
# Epoch 125/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4458 - accuracy: 0.7866 - val_loss: 0.5865 - val_accuracy: 0.7143
# Epoch 126/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4316 - accuracy: 0.7883 - val_loss: 0.6080 - val_accuracy: 0.7208
# Epoch 127/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4185 - accuracy: 0.7948 - val_loss: 0.5396 - val_accuracy: 0.7143
# Epoch 128/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4228 - accuracy: 0.7980 - val_loss: 0.6320 - val_accuracy: 0.6948
# Epoch 129/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4207 - accuracy: 0.8013 - val_loss: 0.5735 - val_accuracy: 0.7078
# Epoch 130/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4998 - accuracy: 0.7248 - val_loss: 0.5329 - val_accuracy: 0.6948
# Epoch 131/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4561 - accuracy: 0.7866 - val_loss: 0.5434 - val_accuracy: 0.7143
# Epoch 132/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4315 - accuracy: 0.7850 - val_loss: 0.6084 - val_accuracy: 0.7078
# Epoch 133/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4201 - accuracy: 0.7932 - val_loss: 0.5540 - val_accuracy: 0.7143
# Epoch 134/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4175 - accuracy: 0.7834 - val_loss: 0.5277 - val_accuracy: 0.7143
# Epoch 135/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4103 - accuracy: 0.8013 - val_loss: 0.6043 - val_accuracy: 0.7143
# Epoch 136/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4043 - accuracy: 0.8225 - val_loss: 0.5403 - val_accuracy: 0.7013
# Epoch 137/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3993 - accuracy: 0.8208 - val_loss: 0.6385 - val_accuracy: 0.7143
# Epoch 138/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3966 - accuracy: 0.8371 - val_loss: 0.6317 - val_accuracy: 0.6883
# Epoch 139/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4384 - accuracy: 0.7850 - val_loss: 0.6365 - val_accuracy: 0.7208
# Epoch 140/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4073 - accuracy: 0.8225 - val_loss: 0.7167 - val_accuracy: 0.6883
# Epoch 141/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4000 - accuracy: 0.8176 - val_loss: 0.6054 - val_accuracy: 0.7013
# Epoch 142/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3906 - accuracy: 0.8176 - val_loss: 0.6271 - val_accuracy: 0.7338
# Epoch 143/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3974 - accuracy: 0.8306 - val_loss: 0.6201 - val_accuracy: 0.7013
# Epoch 144/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3828 - accuracy: 0.8274 - val_loss: 0.6165 - val_accuracy: 0.6883
# Epoch 145/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3966 - accuracy: 0.8143 - val_loss: 0.6710 - val_accuracy: 0.6883
# Epoch 146/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3858 - accuracy: 0.8208 - val_loss: 0.5924 - val_accuracy: 0.7468
# Epoch 147/150
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4130 - accuracy: 0.7964 - val_loss: 0.6043 - val_accuracy: 0.7143
# Epoch 148/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4229 - accuracy: 0.7948 - val_loss: 0.6221 - val_accuracy: 0.6948
# Epoch 149/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4326 - accuracy: 0.7997 - val_loss: 0.6036 - val_accuracy: 0.6753
# Epoch 150/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4135 - accuracy: 0.8257 - val_loss: 0.5998 - val_accuracy: 0.7208

# %% [markdown]
# ### Сохранение модели
#
# За запись чекпоинтов в keras отвечает **tf.keras.callbacks.ModelCheckpoint**. Как видно из пути к модулю -- он относится к коллбекам (callbacks). Можно смотреть на них как на функции, которые вызывает метод model.fit внутри себя.
#
# То есть каждый раз, когда отработает одна из эпох цикла, будет запускаться функция, которую мы укажем. Бывают коллбеки, которые вызываются на каждой итерации (например [прогресс бар](https://keras.io/callbacks/#progbarlogger), который мы видим при обучении -- это тоже коллбэк). Чуть ниже мы разберем конкретный пример.
#
# Вернемся к **tf.keras.callbacks.ModelCheckpoint**.
#
# ```
# tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', ...)
# ```
#
# Он имеет один обязательный параметр -- имя чекпоинта. Оно может быть отформатировано с использованием служебных переменных (пример ниже). Из необязательных, но полезных параметров:
#
# *   monitor (str): название метрики за которой нужно "следить"
# *   verbose -- печатать ли дополнительную информацию
# *   save_best_only (bool): сохранять чекпоинт только после улучшения метрики, указанной в monitor
# *   save_weights_only (bool): помимо весов модели можно еще сохранять ее архитектуру и состояние оптимизатора. В примерах мы так и будем делать, если не сказано обратное. По умолчанию -- false.
# *   mode (str): если метрику нужно максимизировать -- max, иначе -- min.
#
#
# **Таким образом, если выбрано save_best_only, то чекпоинты будут сохранятся только после тех эпох, когда произошло улучшение метрики, которую мы указали в monitor. Т.к. понятие "лучше" -- разное для разных метрик, необходимо также указать режим -- max/min (больше -- лучше/меньше -- лучше). Пример таких метрик -- лосс (min) и точность (max)**.

# %%
from pathlib import Path
path = Path("model_1")
path.mkdir(exist_ok=True) # создаем папку на диске
cpt_filename = "{epoch:02d}_checkpoint_{val_loss:.2f}.hdf5"  
cpt_path = str(path / cpt_filename)

checkpoint = tf.keras.callbacks.ModelCheckpoint(cpt_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
tf.keras.callbacks.ModelCheckpoint?

# %%
"a={a_val}, b={b_val}".format(a_val=2, b_val=34)
# Out:
# 'a=2, b=34'

# %%
cpt_path
# Out:
# 'model_1/{epoch:02d}_checkpoint_{val_loss:.2f}.hdf5'

# %%
# внутри цикла имя чекпоинта будет сгенерировано примерно таким образом:
for epoch in range(4):
  print(cpt_path.format(epoch=epoch, val_acc=np.random.rand()))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-223f6404abcd> in <module>()
#       1 # внутри цикла имя чекпоинта будет сгенерировано примерно таким образом:
#       2 for epoch in range(4):
# ----> 3   print(cpt_path.format(epoch=epoch, val_acc=np.random.rand()))
#
# KeyError: 'val_loss'

# %% [markdown]
# Мы используем hdf5 -- основной формат для keras. Для Tensorflow -- это ckpt. Сохранять в этом расширении можно аналогичным образом. Подробнее можно прочитать [здесь](https://www.tensorflow.org/tutorials/keras/save_and_restore_models).

# %%
model = get_compiled_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=64, verbose=0, 
          callbacks=[checkpoint])
# Out:
# Epoch 00001: val_loss improved from inf to 1.01548, saving model to model_1/01_checkpoint_1.02.hdf5model_1/01_checkpoint_1.02.hdf5
#
# Epoch 00002: val_loss improved from 1.01548 to 0.70709, saving model to model_1/02_checkpoint_0.71.hdf5model_1/02_checkpoint_0.71.hdf5
#
# Epoch 00003: val_loss improved from 0.70709 to 0.64010, saving model to model_1/03_checkpoint_0.64.hdf5model_1/03_checkpoint_0.64.hdf5
#
# Epoch 00004: val_loss improved from 0.64010 to 0.60860, saving model to model_1/04_checkpoint_0.61.hdf5model_1/04_checkpoint_0.61.hdf5
#
# Epoch 00005: val_loss improved from 0.60860 to 0.59486, saving model to model_1/05_checkpoint_0.59.hdf5model_1/05_checkpoint_0.59.hdf5
#
# Epoch 00006: val_loss did not improve from 0.59486
#
# Epoch 00007: val_loss did not improve from 0.59486
#
# Epoch 00008: val_loss improved from 0.59486 to 0.58603, saving model to model_1/08_checkpoint_0.59.hdf5model_1/08_checkpoint_0.59.hdf5
#
# Epoch 00009: val_loss did not improve from 0.58603
#
# Epoch 00010: val_loss did not improve from 0.58603
#
# Epoch 00011: val_loss did not improve from 0.58603
#
# Epoch 00012: val_loss did not improve from 0.58603
#
# Epoch 00013: val_loss did not improve from 0.58603
#
# Epoch 00014: val_loss did not improve from 0.58603
#
# Epoch 00015: val_loss did not improve from 0.58603
#
# Epoch 00016: val_loss did not improve from 0.58603
#
# Epoch 00017: val_loss did not improve from 0.58603
#
# Epoch 00018: val_loss did not improve from 0.58603
#
# Epoch 00019: val_loss did not improve from 0.58603
#
# Epoch 00020: val_loss improved from 0.58603 to 0.57379, saving model to model_1/20_checkpoint_0.57.hdf5model_1/20_checkpoint_0.57.hdf5
#
# Epoch 00021: val_loss did not improve from 0.57379
#
# Epoch 00022: val_loss did not improve from 0.57379
#
# Epoch 00023: val_loss did not improve from 0.57379
#
# Epoch 00024: val_loss did not improve from 0.57379
#
# Epoch 00025: val_loss did not improve from 0.57379
#
# Epoch 00026: val_loss did not improve from 0.57379
#
# Epoch 00027: val_loss did not improve from 0.57379
#
# Epoch 00028: val_loss did not improve from 0.57379
#
# Epoch 00029: val_loss did not improve from 0.57379
#
# Epoch 00030: val_loss did not improve from 0.57379
#
# Epoch 00031: val_loss did not improve from 0.57379
#
# Epoch 00032: val_loss did not improve from 0.57379
#
# Epoch 00033: val_loss did not improve from 0.57379
#
# Epoch 00034: val_loss did not improve from 0.57379
#
# Epoch 00035: val_loss did not improve from 0.57379
#
# Epoch 00036: val_loss improved from 0.57379 to 0.57311, saving model to model_1/36_checkpoint_0.57.hdf5model_1/36_checkpoint_0.57.hdf5
#
# Epoch 00037: val_loss did not improve from 0.57311
#
# Epoch 00038: val_loss did not improve from 0.57311
#
# Epoch 00039: val_loss did not improve from 0.57311
#
# Epoch 00040: val_loss did not improve from 0.57311
#
# Epoch 00041: val_loss did not improve from 0.57311
#
# Epoch 00042: val_loss did not improve from 0.57311
#
# Epoch 00043: val_loss improved from 0.57311 to 0.56955, saving model to model_1/43_checkpoint_0.57.hdf5model_1/43_checkpoint_0.57.hdf5
#
# Epoch 00044: val_loss did not improve from 0.56955
#
# Epoch 00045: val_loss did not improve from 0.56955
#
# Epoch 00046: val_loss did not improve from 0.56955
#
# Epoch 00047: val_loss did not improve from 0.56955
#
# Epoch 00048: val_loss did not improve from 0.56955
#
# Epoch 00049: val_loss did not improve from 0.56955
#
# Epoch 00050: val_loss did not improve from 0.56955
#
# Epoch 00051: val_loss did not improve from 0.56955
#
# Epoch 00052: val_loss did not improve from 0.56955
#
# Epoch 00053: val_loss did not improve from 0.56955
#
# Epoch 00054: val_loss did not improve from 0.56955
#
# Epoch 00055: val_loss did not improve from 0.56955
#
# Epoch 00056: val_loss did not improve from 0.56955
#
# Epoch 00057: val_loss did not improve from 0.56955
#
# Epoch 00058: val_loss did not improve from 0.56955
#
# Epoch 00059: val_loss did not improve from 0.56955
#
# Epoch 00060: val_loss did not improve from 0.56955
#
# Epoch 00061: val_loss did not improve from 0.56955
#
# Epoch 00062: val_loss did not improve from 0.56955
#
# Epoch 00063: val_loss did not improve from 0.56955
#
# Epoch 00064: val_loss did not improve from 0.56955
#
# Epoch 00065: val_loss did not improve from 0.56955
#
# Epoch 00066: val_loss did not improve from 0.56955
#
# Epoch 00067: val_loss did not improve from 0.56955
#
# Epoch 00068: val_loss did not improve from 0.56955
#
# Epoch 00069: val_loss did not improve from 0.56955
#
# Epoch 00070: val_loss did not improve from 0.56955
#
# Epoch 00071: val_loss improved from 0.56955 to 0.56098, saving model to model_1/71_checkpoint_0.56.hdf5model_1/71_checkpoint_0.56.hdf5
#
# Epoch 00072: val_loss did not improve from 0.56098
#
# Epoch 00073: val_loss improved from 0.56098 to 0.55640, saving model to model_1/73_checkpoint_0.56.hdf5model_1/73_checkpoint_0.56.hdf5
#
# Epoch 00074: val_loss did not improve from 0.55640
#
# Epoch 00075: val_loss did not improve from 0.55640
#
# Epoch 00076: val_loss did not improve from 0.55640
#
# Epoch 00077: val_loss did not improve from 0.55640
#
# Epoch 00078: val_loss did not improve from 0.55640
#
# Epoch 00079: val_loss did not improve from 0.55640
#
# Epoch 00080: val_loss did not improve from 0.55640
#
# Epoch 00081: val_loss did not improve from 0.55640
#
# Epoch 00082: val_loss did not improve from 0.55640
#
# Epoch 00083: val_loss did not improve from 0.55640
#
# Epoch 00084: val_loss did not improve from 0.55640
#
# Epoch 00085: val_loss did not improve from 0.55640
#
# Epoch 00086: val_loss did not improve from 0.55640
#
# Epoch 00087: val_loss improved from 0.55640 to 0.54824, saving model to model_1/87_checkpoint_0.55.hdf5model_1/87_checkpoint_0.55.hdf5
#
# Epoch 00088: val_loss did not improve from 0.54824
#
# Epoch 00089: val_loss did not improve from 0.54824
#
# Epoch 00090: val_loss did not improve from 0.54824
#
# Epoch 00091: val_loss did not improve from 0.54824
#
# Epoch 00092: val_loss did not improve from 0.54824
#
# Epoch 00093: val_loss did not improve from 0.54824
#
# Epoch 00094: val_loss did not improve from 0.54824
#
# Epoch 00095: val_loss improved from 0.54824 to 0.52028, saving model to model_1/95_checkpoint_0.52.hdf5model_1/95_checkpoint_0.52.hdf5
#
# Epoch 00096: val_loss did not improve from 0.52028
#
# Epoch 00097: val_loss did not improve from 0.52028
#
# Epoch 00098: val_loss did not improve from 0.52028
#
# Epoch 00099: val_loss did not improve from 0.52028
#
# Epoch 00100: val_loss did not improve from 0.52028
#
# Epoch 00101: val_loss did not improve from 0.52028
#
# Epoch 00102: val_loss did not improve from 0.52028
#
# Epoch 00103: val_loss did not improve from 0.52028
#
# Epoch 00104: val_loss did not improve from 0.52028
#
# Epoch 00105: val_loss did not improve from 0.52028
#
# Epoch 00106: val_loss did not improve from 0.52028
#
# Epoch 00107: val_loss did not improve from 0.52028
#
# Epoch 00108: val_loss did not improve from 0.52028
#
# Epoch 00109: val_loss improved from 0.52028 to 0.50696, saving model to model_1/109_checkpoint_0.51.hdf5model_1/109_checkpoint_0.51.hdf5
#
# Epoch 00110: val_loss did not improve from 0.50696
#
# Epoch 00111: val_loss did not improve from 0.50696
#
# Epoch 00112: val_loss did not improve from 0.50696
#
# Epoch 00113: val_loss did not improve from 0.50696
#
# Epoch 00114: val_loss did not improve from 0.50696
#
# Epoch 00115: val_loss did not improve from 0.50696
#
# Epoch 00116: val_loss did not improve from 0.50696
#
# Epoch 00117: val_loss did not improve from 0.50696
#
# Epoch 00118: val_loss did not improve from 0.50696
#
# Epoch 00119: val_loss did not improve from 0.50696
#
# Epoch 00120: val_loss did not improve from 0.50696
#
# Epoch 00121: val_loss did not improve from 0.50696
#
# Epoch 00122: val_loss did not improve from 0.50696
#
# Epoch 00123: val_loss did not improve from 0.50696
#
# Epoch 00124: val_loss did not improve from 0.50696
#
# Epoch 00125: val_loss did not improve from 0.50696
#
# Epoch 00126: val_loss did not improve from 0.50696
#
# Epoch 00127: val_loss did not improve from 0.50696
#
# Epoch 00128: val_loss did not improve from 0.50696
#
# Epoch 00129: val_loss did not improve from 0.50696
#
# Epoch 00130: val_loss did not improve from 0.50696
#
# Epoch 00131: val_loss did not improve from 0.50696
#
# Epoch 00132: val_loss did not improve from 0.50696
#
# Epoch 00133: val_loss did not improve from 0.50696
#
# Epoch 00134: val_loss did not improve from 0.50696
#
# Epoch 00135: val_loss did not improve from 0.50696
#
# Epoch 00136: val_loss did not improve from 0.50696
#
# Epoch 00137: val_loss did not improve from 0.50696
#
# Epoch 00138: val_loss did not improve from 0.50696
#
# Epoch 00139: val_loss did not improve from 0.50696
#
# Epoch 00140: val_loss did not improve from 0.50696
#
# Epoch 00141: val_loss did not improve from 0.50696
#
# Epoch 00142: val_loss did not improve from 0.50696
#
# Epoch 00143: val_loss did not improve from 0.50696
#
# Epoch 00144: val_loss did not improve from 0.50696
#
# Epoch 00145: val_loss did not improve from 0.50696
#
# Epoch 00146: val_loss did not improve from 0.50696
#
# Epoch 00147: val_loss did not improve from 0.50696
#
# Epoch 00148: val_loss did not improve from 0.50696
#
# Epoch 00149: val_loss did not improve from 0.50696
#
# Epoch 00150: val_loss did not improve from 0.50696

# %% [markdown]
# Убедимся ниже, что файлы сохранены:

# %%
! ls "model_1/"
# Out:
# 01_checkpoint_0.88.hdf5  114_checkpoint_0.51.hdf5  34_checkpoint_0.57.hdf5
# 02_checkpoint_0.73.hdf5  116_checkpoint_0.50.hdf5  35_checkpoint_0.57.hdf5
# 03_checkpoint_0.71.hdf5  11_checkpoint_0.60.hdf5   36_checkpoint_0.55.hdf5
# 04_checkpoint_0.64.hdf5  137_checkpoint_0.48.hdf5  45_checkpoint_0.53.hdf5
# 07_checkpoint_0.63.hdf5  18_checkpoint_0.59.hdf5   62_checkpoint_0.52.hdf5
# 08_checkpoint_0.61.hdf5  21_checkpoint_0.58.hdf5   78_checkpoint_0.51.hdf5

# %% [markdown]
# ### Загрузка модели
#
# Загрузить модель можно двумя способами. Определить модель и загрузить в нее веса, с использованием *model.load_weights()*. Или tf.keras.models.load_model для автоматического создания модели и загрузки весов (мы можем так сделать т.к. при создании чекпоинтов выставили save_weights_only=False, т.е. сохранили и описание модели).

# %%
model = get_compiled_model() # определим случайно инициализированную модель
loss, acc = model.evaluate(X_test, y_test)
print(f"Accuracy of random model {acc*100 :.2f}%")
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 6.9876 - accuracy: 0.5000
# Accuracy of random model 50.00%

# %%
model.load_weights("model_1/95_checkpoint_0.79.hdf5") # загружаем веса. обратите внимание, модель уже создана!
loss, acc = model.evaluate(X_test, y_test)
print(f"Accuracy of restored model {acc*100 :.2f}%")
# Out:
# 154/154 [==============================] - 0s 69us/sample - loss: 0.4846 - acc: 0.7922
# Accuracy of restored model 79.22%

# %%
# т.к. мы сохраняли и веса и модель, то мы можем загрузить модель не определяя ее
model = tf.keras.models.load_model("model_1/95_checkpoint_0.79.hdf5")
loss, acc = model.evaluate(X_test, y_test)
print(f"Accuracy of restored model {acc*100 :.2f}%")
# Out:
# 154/154 [==============================] - 0s 310us/sample - loss: 0.4846 - acc: 0.7922
# Accuracy of restored model 79.22%

# %% [markdown]
# ### Сохранение модели в один чекпоинт
# Если не форматировать название файла, то все чекпоинты будут записаны в него:

# %%
path = Path("model_2")
path.mkdir(exist_ok=True)
cpt_filename = "checkpoint_best.hdf5"
cpt_path =str(path / cpt_filename)

checkpoint = tf.keras.callbacks.ModelCheckpoint(cpt_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

model = get_compiled_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=64, verbose=0, 
          callbacks=[checkpoint])
# Out:
# Epoch 00001: val_acc improved from -inf to 0.59740, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00002: val_acc improved from 0.59740 to 0.61688, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00003: val_acc improved from 0.61688 to 0.62338, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00004: val_acc did not improve from 0.62338
#
# Epoch 00005: val_acc did not improve from 0.62338
#
# Epoch 00006: val_acc improved from 0.62338 to 0.64935, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00007: val_acc did not improve from 0.64935
#
# Epoch 00008: val_acc improved from 0.64935 to 0.66883, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00009: val_acc improved from 0.66883 to 0.68831, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00010: val_acc did not improve from 0.68831
#
# Epoch 00011: val_acc improved from 0.68831 to 0.69481, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00012: val_acc did not improve from 0.69481
#
# Epoch 00013: val_acc did not improve from 0.69481
#
# Epoch 00014: val_acc did not improve from 0.69481
#
# Epoch 00015: val_acc did not improve from 0.69481
#
# Epoch 00016: val_acc did not improve from 0.69481
#
# Epoch 00017: val_acc did not improve from 0.69481
#
# Epoch 00018: val_acc improved from 0.69481 to 0.71429, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00019: val_acc did not improve from 0.71429
#
# Epoch 00020: val_acc did not improve from 0.71429
#
# Epoch 00021: val_acc did not improve from 0.71429
#
# Epoch 00022: val_acc did not improve from 0.71429
#
# Epoch 00023: val_acc improved from 0.71429 to 0.72727, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00024: val_acc did not improve from 0.72727
#
# Epoch 00025: val_acc did not improve from 0.72727
#
# Epoch 00026: val_acc did not improve from 0.72727
#
# Epoch 00027: val_acc did not improve from 0.72727
#
# Epoch 00028: val_acc did not improve from 0.72727
#
# Epoch 00029: val_acc did not improve from 0.72727
#
# Epoch 00030: val_acc did not improve from 0.72727
#
# Epoch 00031: val_acc did not improve from 0.72727
#
# Epoch 00032: val_acc did not improve from 0.72727
#
# Epoch 00033: val_acc did not improve from 0.72727
#
# Epoch 00034: val_acc did not improve from 0.72727
#
# Epoch 00035: val_acc did not improve from 0.72727
#
# Epoch 00036: val_acc did not improve from 0.72727
#
# Epoch 00037: val_acc did not improve from 0.72727
#
# Epoch 00038: val_acc did not improve from 0.72727
#
# Epoch 00039: val_acc did not improve from 0.72727
#
# Epoch 00040: val_acc did not improve from 0.72727
#
# Epoch 00041: val_acc did not improve from 0.72727
#
# Epoch 00042: val_acc did not improve from 0.72727
#
# Epoch 00043: val_acc did not improve from 0.72727
#
# Epoch 00044: val_acc did not improve from 0.72727
#
# Epoch 00045: val_acc improved from 0.72727 to 0.74026, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00046: val_acc did not improve from 0.74026
#
# Epoch 00047: val_acc did not improve from 0.74026
#
# Epoch 00048: val_acc did not improve from 0.74026
#
# Epoch 00049: val_acc did not improve from 0.74026
#
# Epoch 00050: val_acc did not improve from 0.74026
#
# Epoch 00051: val_acc did not improve from 0.74026
#
# Epoch 00052: val_acc did not improve from 0.74026
#
# Epoch 00053: val_acc did not improve from 0.74026
#
# Epoch 00054: val_acc did not improve from 0.74026
#
# Epoch 00055: val_acc did not improve from 0.74026
#
# Epoch 00056: val_acc did not improve from 0.74026
#
# Epoch 00057: val_acc improved from 0.74026 to 0.75325, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00058: val_acc did not improve from 0.75325
#
# Epoch 00059: val_acc did not improve from 0.75325
#
# Epoch 00060: val_acc did not improve from 0.75325
#
# Epoch 00061: val_acc did not improve from 0.75325
#
# Epoch 00062: val_acc did not improve from 0.75325
#
# Epoch 00063: val_acc did not improve from 0.75325
#
# Epoch 00064: val_acc did not improve from 0.75325
#
# Epoch 00065: val_acc did not improve from 0.75325
#
# Epoch 00066: val_acc did not improve from 0.75325
#
# Epoch 00067: val_acc did not improve from 0.75325
#
# Epoch 00068: val_acc did not improve from 0.75325
#
# Epoch 00069: val_acc did not improve from 0.75325
#
# Epoch 00070: val_acc did not improve from 0.75325
#
# Epoch 00071: val_acc did not improve from 0.75325
#
# Epoch 00072: val_acc did not improve from 0.75325
#
# Epoch 00073: val_acc did not improve from 0.75325
#
# Epoch 00074: val_acc did not improve from 0.75325
#
# Epoch 00075: val_acc did not improve from 0.75325
#
# Epoch 00076: val_acc did not improve from 0.75325
#
# Epoch 00077: val_acc did not improve from 0.75325
#
# Epoch 00078: val_acc did not improve from 0.75325
#
# Epoch 00079: val_acc did not improve from 0.75325
#
# Epoch 00080: val_acc did not improve from 0.75325
#
# Epoch 00081: val_acc did not improve from 0.75325
#
# Epoch 00082: val_acc improved from 0.75325 to 0.76623, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00083: val_acc did not improve from 0.76623
#
# Epoch 00084: val_acc did not improve from 0.76623
#
# Epoch 00085: val_acc did not improve from 0.76623
#
# Epoch 00086: val_acc did not improve from 0.76623
#
# Epoch 00087: val_acc did not improve from 0.76623
#
# Epoch 00088: val_acc did not improve from 0.76623
#
# Epoch 00089: val_acc did not improve from 0.76623
#
# Epoch 00090: val_acc did not improve from 0.76623
#
# Epoch 00091: val_acc did not improve from 0.76623
#
# Epoch 00092: val_acc did not improve from 0.76623
#
# Epoch 00093: val_acc did not improve from 0.76623
#
# Epoch 00094: val_acc did not improve from 0.76623
#
# Epoch 00095: val_acc did not improve from 0.76623
#
# Epoch 00096: val_acc did not improve from 0.76623
#
# Epoch 00097: val_acc did not improve from 0.76623
#
# Epoch 00098: val_acc did not improve from 0.76623
#
# Epoch 00099: val_acc did not improve from 0.76623
#
# Epoch 00100: val_acc did not improve from 0.76623
#
# Epoch 00101: val_acc did not improve from 0.76623
#
# Epoch 00102: val_acc did not improve from 0.76623
#
# Epoch 00103: val_acc did not improve from 0.76623
#
# Epoch 00104: val_acc did not improve from 0.76623
#
# Epoch 00105: val_acc did not improve from 0.76623
#
# Epoch 00106: val_acc did not improve from 0.76623
#
# Epoch 00107: val_acc did not improve from 0.76623
#
# Epoch 00108: val_acc did not improve from 0.76623
#
# Epoch 00109: val_acc did not improve from 0.76623
#
# Epoch 00110: val_acc did not improve from 0.76623
#
# Epoch 00111: val_acc did not improve from 0.76623
#
# Epoch 00112: val_acc did not improve from 0.76623
#
# Epoch 00113: val_acc did not improve from 0.76623
#
# Epoch 00114: val_acc did not improve from 0.76623
#
# Epoch 00115: val_acc did not improve from 0.76623
#
# Epoch 00116: val_acc did not improve from 0.76623
#
# Epoch 00117: val_acc did not improve from 0.76623
#
# Epoch 00118: val_acc did not improve from 0.76623
#
# Epoch 00119: val_acc did not improve from 0.76623
#
# Epoch 00120: val_acc did not improve from 0.76623
#
# Epoch 00121: val_acc did not improve from 0.76623
#
# Epoch 00122: val_acc did not improve from 0.76623
#
# Epoch 00123: val_acc did not improve from 0.76623
#
# Epoch 00124: val_acc did not improve from 0.76623
#
# Epoch 00125: val_acc did not improve from 0.76623
#
# Epoch 00126: val_acc did not improve from 0.76623
#
# Epoch 00127: val_acc did not improve from 0.76623
#
# Epoch 00128: val_acc did not improve from 0.76623
#
# Epoch 00129: val_acc did not improve from 0.76623
#
# Epoch 00130: val_acc did not improve from 0.76623
#
# Epoch 00131: val_acc did not improve from 0.76623
#
# Epoch 00132: val_acc did not improve from 0.76623
#
# Epoch 00133: val_acc did not improve from 0.76623
#
# Epoch 00134: val_acc did not improve from 0.76623
#
# Epoch 00135: val_acc did not improve from 0.76623
#
# Epoch 00136: val_acc did not improve from 0.76623
#
# Epoch 00137: val_acc did not improve from 0.76623
#
# Epoch 00138: val_acc did not improve from 0.76623
#
# Epoch 00139: val_acc did not improve from 0.76623
#
# Epoch 00140: val_acc did not improve from 0.76623
#
# Epoch 00141: val_acc did not improve from 0.76623
#
# Epoch 00142: val_acc did not improve from 0.76623
#
# Epoch 00143: val_acc did not improve from 0.76623
#
# Epoch 00144: val_acc did not improve from 0.76623
#
# Epoch 00145: val_acc did not improve from 0.76623
#
# Epoch 00146: val_acc did not improve from 0.76623
#
# Epoch 00147: val_acc did not improve from 0.76623
#
# Epoch 00148: val_acc did not improve from 0.76623
#
# Epoch 00149: val_acc did not improve from 0.76623
#
# Epoch 00150: val_acc did not improve from 0.76623

# %%
! ls model_2
# Out:
# checkpoint_best.hdf5

# %%
model = tf.keras.models.load_model("model_2/checkpoint_best.hdf5")
loss, acc = model.evaluate(X_test, y_test)
print(f"Accuracy of restored model {acc*100 :.2f}%")
# Out:
# 154/154 [==============================] - 0s 329us/sample - loss: 0.4982 - acc: 0.7662
# Accuracy of restored model 76.62%

# %% [markdown]
# Сохранять один файл или несколько -- решать вам, это зависит от задач и принятых практик ведения экспериментов, например, в каких-то случаях может пригодится сравнить предсказания нескольких последних моделей.

# %% [markdown]
# ### Продолжение процесса обучения

# %%
# мы можем продолжить процесс обучения, обратите внимание на initial_epoch
model = tf.keras.models.load_model("model_2/checkpoint_best.hdf5")
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=300, batch_size=64, verbose=0, 
          callbacks=[checkpoint], initial_epoch=150)
# Out:
# Epoch 00151: val_acc did not improve from 0.76623
#
# Epoch 00152: val_acc did not improve from 0.76623
#
# Epoch 00153: val_acc did not improve from 0.76623
#
# Epoch 00154: val_acc did not improve from 0.76623
#
# Epoch 00155: val_acc did not improve from 0.76623
#
# Epoch 00156: val_acc did not improve from 0.76623
#
# Epoch 00157: val_acc did not improve from 0.76623
#
# Epoch 00158: val_acc did not improve from 0.76623
#
# Epoch 00159: val_acc did not improve from 0.76623
#
# Epoch 00160: val_acc did not improve from 0.76623
#
# Epoch 00161: val_acc did not improve from 0.76623
#
# Epoch 00162: val_acc did not improve from 0.76623
#
# Epoch 00163: val_acc did not improve from 0.76623
#
# Epoch 00164: val_acc did not improve from 0.76623
#
# Epoch 00165: val_acc did not improve from 0.76623
#
# Epoch 00166: val_acc did not improve from 0.76623
#
# Epoch 00167: val_acc did not improve from 0.76623
#
# Epoch 00168: val_acc did not improve from 0.76623
#
# Epoch 00169: val_acc did not improve from 0.76623
#
# Epoch 00170: val_acc did not improve from 0.76623
#
# Epoch 00171: val_acc did not improve from 0.76623
#
# Epoch 00172: val_acc did not improve from 0.76623
#
# Epoch 00173: val_acc did not improve from 0.76623
#
# Epoch 00174: val_acc did not improve from 0.76623
#
# Epoch 00175: val_acc did not improve from 0.76623
#
# Epoch 00176: val_acc did not improve from 0.76623
#
# Epoch 00177: val_acc did not improve from 0.76623
#
# Epoch 00178: val_acc did not improve from 0.76623
#
# Epoch 00179: val_acc did not improve from 0.76623
#
# Epoch 00180: val_acc did not improve from 0.76623
#
# Epoch 00181: val_acc did not improve from 0.76623
#
# Epoch 00182: val_acc did not improve from 0.76623
#
# Epoch 00183: val_acc did not improve from 0.76623
#
# Epoch 00184: val_acc did not improve from 0.76623
#
# Epoch 00185: val_acc did not improve from 0.76623
#
# Epoch 00186: val_acc did not improve from 0.76623
#
# Epoch 00187: val_acc did not improve from 0.76623
#
# Epoch 00188: val_acc did not improve from 0.76623
#
# Epoch 00189: val_acc did not improve from 0.76623
#
# Epoch 00190: val_acc did not improve from 0.76623
#
# Epoch 00191: val_acc did not improve from 0.76623
#
# Epoch 00192: val_acc did not improve from 0.76623
#
# Epoch 00193: val_acc did not improve from 0.76623
#
# Epoch 00194: val_acc did not improve from 0.76623
#
# Epoch 00195: val_acc did not improve from 0.76623
#
# Epoch 00196: val_acc did not improve from 0.76623
#
# Epoch 00197: val_acc did not improve from 0.76623
#
# Epoch 00198: val_acc did not improve from 0.76623
#
# Epoch 00199: val_acc did not improve from 0.76623
#
# Epoch 00200: val_acc did not improve from 0.76623
#
# Epoch 00201: val_acc did not improve from 0.76623
#
# Epoch 00202: val_acc did not improve from 0.76623
#
# Epoch 00203: val_acc did not improve from 0.76623
#
# Epoch 00204: val_acc did not improve from 0.76623
#
# Epoch 00205: val_acc did not improve from 0.76623
#
# Epoch 00206: val_acc did not improve from 0.76623
#
# Epoch 00207: val_acc did not improve from 0.76623
#
# Epoch 00208: val_acc did not improve from 0.76623
#
# Epoch 00209: val_acc did not improve from 0.76623
#
# Epoch 00210: val_acc did not improve from 0.76623
#
# Epoch 00211: val_acc did not improve from 0.76623
#
# Epoch 00212: val_acc did not improve from 0.76623
#
# Epoch 00213: val_acc did not improve from 0.76623
#
# Epoch 00214: val_acc did not improve from 0.76623
#
# Epoch 00215: val_acc did not improve from 0.76623
#
# Epoch 00216: val_acc did not improve from 0.76623
#
# Epoch 00217: val_acc did not improve from 0.76623
#
# Epoch 00218: val_acc did not improve from 0.76623
#
# Epoch 00219: val_acc did not improve from 0.76623
#
# Epoch 00220: val_acc did not improve from 0.76623
#
# Epoch 00221: val_acc did not improve from 0.76623
#
# Epoch 00222: val_acc did not improve from 0.76623
#
# Epoch 00223: val_acc did not improve from 0.76623
#
# Epoch 00224: val_acc did not improve from 0.76623
#
# Epoch 00225: val_acc did not improve from 0.76623
#
# Epoch 00226: val_acc did not improve from 0.76623
#
# Epoch 00227: val_acc did not improve from 0.76623
#
# Epoch 00228: val_acc did not improve from 0.76623
#
# Epoch 00229: val_acc did not improve from 0.76623
#
# Epoch 00230: val_acc did not improve from 0.76623
#
# Epoch 00231: val_acc did not improve from 0.76623
#
# Epoch 00232: val_acc improved from 0.76623 to 0.77922, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00233: val_acc did not improve from 0.77922
#
# Epoch 00234: val_acc did not improve from 0.77922
#
# Epoch 00235: val_acc did not improve from 0.77922
#
# Epoch 00236: val_acc did not improve from 0.77922
#
# Epoch 00237: val_acc did not improve from 0.77922
#
# Epoch 00238: val_acc did not improve from 0.77922
#
# Epoch 00239: val_acc did not improve from 0.77922
#
# Epoch 00240: val_acc did not improve from 0.77922
#
# Epoch 00241: val_acc did not improve from 0.77922
#
# Epoch 00242: val_acc did not improve from 0.77922
#
# Epoch 00243: val_acc did not improve from 0.77922
#
# Epoch 00244: val_acc did not improve from 0.77922
#
# Epoch 00245: val_acc did not improve from 0.77922
#
# Epoch 00246: val_acc did not improve from 0.77922
#
# Epoch 00247: val_acc did not improve from 0.77922
#
# Epoch 00248: val_acc did not improve from 0.77922
#
# Epoch 00249: val_acc did not improve from 0.77922
#
# Epoch 00250: val_acc did not improve from 0.77922
#
# Epoch 00251: val_acc did not improve from 0.77922
#
# Epoch 00252: val_acc did not improve from 0.77922
#
# Epoch 00253: val_acc did not improve from 0.77922
#
# Epoch 00254: val_acc did not improve from 0.77922
#
# Epoch 00255: val_acc did not improve from 0.77922
#
# Epoch 00256: val_acc did not improve from 0.77922
#
# Epoch 00257: val_acc did not improve from 0.77922
#
# Epoch 00258: val_acc did not improve from 0.77922
#
# Epoch 00259: val_acc did not improve from 0.77922
#
# Epoch 00260: val_acc did not improve from 0.77922
#
# Epoch 00261: val_acc did not improve from 0.77922
#
# Epoch 00262: val_acc did not improve from 0.77922
#
# Epoch 00263: val_acc did not improve from 0.77922
#
# Epoch 00264: val_acc did not improve from 0.77922
#
# Epoch 00265: val_acc did not improve from 0.77922
#
# Epoch 00266: val_acc did not improve from 0.77922
#
# Epoch 00267: val_acc did not improve from 0.77922
#
# Epoch 00268: val_acc did not improve from 0.77922
#
# Epoch 00269: val_acc did not improve from 0.77922
#
# Epoch 00270: val_acc did not improve from 0.77922
#
# Epoch 00271: val_acc did not improve from 0.77922
#
# Epoch 00272: val_acc did not improve from 0.77922
#
# Epoch 00273: val_acc did not improve from 0.77922
#
# Epoch 00274: val_acc did not improve from 0.77922
#
# Epoch 00275: val_acc improved from 0.77922 to 0.78571, saving model to model_2/checkpoint_best.hdf5
#
# Epoch 00276: val_acc did not improve from 0.78571
#
# Epoch 00277: val_acc did not improve from 0.78571
#
# Epoch 00278: val_acc did not improve from 0.78571
#
# Epoch 00279: val_acc did not improve from 0.78571
#
# Epoch 00280: val_acc did not improve from 0.78571
#
# Epoch 00281: val_acc did not improve from 0.78571
#
# Epoch 00282: val_acc did not improve from 0.78571
#
# Epoch 00283: val_acc did not improve from 0.78571
#
# Epoch 00284: val_acc did not improve from 0.78571
#
# Epoch 00285: val_acc did not improve from 0.78571
#
# Epoch 00286: val_acc did not improve from 0.78571
#
# Epoch 00287: val_acc did not improve from 0.78571
#
# Epoch 00288: val_acc did not improve from 0.78571
#
# Epoch 00289: val_acc did not improve from 0.78571
#
# Epoch 00290: val_acc did not improve from 0.78571
#
# Epoch 00291: val_acc did not improve from 0.78571
#
# Epoch 00292: val_acc did not improve from 0.78571
#
# Epoch 00293: val_acc did not improve from 0.78571
#
# Epoch 00294: val_acc did not improve from 0.78571
#
# Epoch 00295: val_acc did not improve from 0.78571
#
# Epoch 00296: val_acc did not improve from 0.78571
#
# Epoch 00297: val_acc did not improve from 0.78571
#
# Epoch 00298: val_acc did not improve from 0.78571
#
# Epoch 00299: val_acc did not improve from 0.78571
#
# Epoch 00300: val_acc did not improve from 0.78571

# %% [markdown]
# ## Заключение
#
# В этом уроке мы узнали как сохранять прогресс обучения и использовать полученные модели.
#
# Следующий этап -- [домашнее задание](https://colab.research.google.com/drive/1G6iHt4PUVrjSHQ80wnCYm3gOtx_Gl1gE), в котором вы примените все полученные знания из этого модуля. Вы снова вернетесь к реализации классификатора известных вам рукописных цифр, но в этот раз сделаете это с помощью Tensorflow.
